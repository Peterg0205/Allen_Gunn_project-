# %%
# dependencies
import pandas as pd 
import requests 
import json
from pprint import pprint 
# api keys
from api_keys import census

# %%
# url = "https://api.census.gov/data/timeseries/poverty/histpov2?get=PCTPOV&time=2017&RACE=1&GEO_ID=1"
# url = "https://api.census.gov/data/2017/acs/acs1?get=NAME,group(B01001)&for=us:1"
url="https://api.census.gov/data/timeseries/poverty/saipe/schdist?get=GEOID,SD_NAME,SAEPOV5_17RV_PT&for=school+district+(Secondary)&YEAR=2017"
# Build query URL
query_url = url + "&key=" + census 

# Get poverty data
pov_response = requests.get(query_url)
pov_json = pov_response.json()

# # Get the temperature from the response
# print(f"The weather API responded with: {weather_json}.")

# %%
pov_response
# Out:
# <Response [200]>

# %%
pov_json
# Out:
# [['GEOID',
#   'SD_NAME',
#   'SAEPOV5_17RV_PT',
#   'YEAR',
#   'state',
#   'school district (secondary)'],
#  ['0400082',
#   'Colorado River Union High School District',
#   '580',
#   '2017',
#   '04',
#   '00082'],
#  ['0400450',
#   'Agua Fria Union High School District',
#   '868',
#   '2017',
#   '04',
#   '00450'],
#  ['0400720',
#   'Antelope Union High School District',
#   '72',
#   '2017',
#   '04',
#   '00720'],
#  ['0401160',
#   'Bicentennial Union High School District',
#   '45',
#   '2017',
#   '04',
#   '01160'],
#  ['0401410',
#   'Buckeye Union High School District',
#   '559',
#   '2017',
#   '04',
#   '01410'],
#  ['0401740',
#   'Casa Grande Union High School District',
#   '913',
#   '2017',
#   '04',
#   '01740'],
#  ['0403450',
#   'Glendale Union High School District',
#   '4880',
#   '2017',
#   '04',
#   '03450'],
#  ['0405070',
#   'Mingus Union High School District',
#   '307',
#   '2017',
#   '04',
#   '05070'],
#  ['0406030',
#   'Patagonia Union High School District',
#   '14',
#   '2017',
#   '04',
#   '06030'],
#  ['0406330',
#   'Phoenix Union High School District',
#   '12330',
#   '2017',
#   '04',
#   '06330'],
#  ['0407530',
#   'Santa Cruz Valley Union High School District',
#   '160',
#   '2017',
#   '04',
#   '07530'],
#  ['0408340',
#   'Tempe Union High School District',
#   '1567',
#   '2017',
#   '04',
#   '08340'],
#  ['0408520',
#   'Tolleson Union High School District',
#   '2238',
#   '2017',
#   '04',
#   '08520'],
#  ['0408910', 'Valley Union High School District', '16', '2017', '04', '08910'],
#  ['0409630', 'Yuma Union High School District', '3123', '2017', '04', '09630'],
#  ['0601650',
#   'Acalanes Union High School District',
#   '160',
#   '2017',
#   '06',
#   '01650'],
#  ['0602630',
#   'Anaheim Union High School District',
#   '7153',
#   '2017',
#   '06',
#   '02630'],
#  ['0602670',
#   'West Sonoma County Union High School District',
#   '182',
#   '2017',
#   '06',
#   '02670'],
#  ['0602700',
#   'Anderson Union High School District',
#   '435',
#   '2017',
#   '06',
#   '02700'],
#  ['0602820',
#   'Antelope Valley Union Joint High School District',
#   '5272',
#   '2017',
#   '06',
#   '02820'],
#  ['0603030',
#   'Northern Humboldt Union High School District',
#   '302',
#   '2017',
#   '06',
#   '03030'],
#  ['0605820',
#   'Brawley Union High School District',
#   '426',
#   '2017',
#   '06',
#   '05820'],
#  ['0605940',
#   'Bret Harte Union High School District',
#   '139',
#   '2017',
#   '06',
#   '05940'],
#  ['0607230',
#   'Campbell Union High School District',
#   '635',
#   '2017',
#   '06',
#   '07230'],
#  ['0607920',
#   'Centinela Valley Union High School District',
#   '1870',
#   '2017',
#   '06',
#   '07920'],
#  ['0608010',
#   'Central Union High School District',
#   '939',
#   '2017',
#   '06',
#   '08010'],
#  ['0608160',
#   'Chaffey Joint Union High School District',
#   '3471',
#   '2017',
#   '06',
#   '08160'],
#  ['0608550',
#   'Chowchilla Union High School District',
#   '308',
#   '2017',
#   '06',
#   '08550'],
#  ['0609810',
#   'Corning Union High School District',
#   '289',
#   '2017',
#   '06',
#   '09810'],
#  ['0610860',
#   'Delano Joint Union High School District',
#   '1435',
#   '2017',
#   '06',
#   '10860'],
#  ['0611700',
#   'Dunsmuir Joint Union High School District',
#   '24',
#   '2017',
#   '06',
#   '11700'],
#  ['0611780',
#   'East Nicolaus Joint Union High School District',
#   '11',
#   '2017',
#   '06',
#   '11780'],
#  ['0611820',
#   'East Side Union High School District',
#   '3075',
#   '2017',
#   '06',
#   '11820'],
#  ['0612070',
#   'El Dorado Union High School District',
#   '578',
#   '2017',
#   '06',
#   '12070'],
#  ['0612120',
#   'El Monte Union High School District',
#   '2248',
#   '2017',
#   '06',
#   '12120'],
#  ['0612910',
#   'Escondido Union High School District',
#   '1505',
#   '2017',
#   '06',
#   '12910'],
#  ['0613530',
#   'Fallbrook Union High School District',
#   '359',
#   '2017',
#   '06',
#   '13530'],
#  ['0614190',
#   'Fortuna Union High School District',
#   '203',
#   '2017',
#   '06',
#   '14190'],
#  ['0614430',
#   'Fremont Union High School District',
#   '423',
#   '2017',
#   '06',
#   '14430'],
#  ['0614760',
#   'Fullerton Joint Union High School District',
#   '2365',
#   '2017',
#   '06',
#   '14760'],
#  ['0614820',
#   'Galt Joint Union High School District',
#   '350',
#   '2017',
#   '06',
#   '14820'],
#  ['0616230',
#   'Grossmont Union High School District',
#   '3561',
#   '2017',
#   '06',
#   '16230'],
#  ['0616500',
#   'Hanford Joint Union High School District',
#   '863',
#   '2017',
#   '06',
#   '16500'],
#  ['0618060',
#   'Huntington Beach Union High School District',
#   '2016',
#   '2017',
#   '06',
#   '18060'],
#  ['0618930',
#   'Jefferson Union High School District',
#   '423',
#   '2017',
#   '06',
#   '18930'],
#  ['0619110', 'Julian Union High School District', '38', '2017', '06', '19110'],
#  ['0619540', 'Kern High School District', '9501', '2017', '06', '19540'],
#  ['0619650',
#   'South Monterey County Joint Union High School District',
#   '468',
#   '2017',
#   '06',
#   '19650'],
#  ['0619830',
#   'Kingsburg Joint Union High School District',
#   '289',
#   '2017',
#   '06',
#   '19830'],
#  ['0621060',
#   'Lassen Union High School District',
#   '130',
#   '2017',
#   '06',
#   '21060'],
#  ['0621270',
#   'Le Grand Union High School District',
#   '256',
#   '2017',
#   '06',
#   '21270'],
#  ['0621400',
#   'Lemoore Union High School District',
#   '415',
#   '2017',
#   '06',
#   '21400'],
#  ['0621600',
#   'Liberty Union High School District',
#   '533',
#   '2017',
#   '06',
#   '21600'],
#  ['0622800',
#   'Los Gatos-Saratoga Joint Union School District',
#   '72',
#   '2017',
#   '06',
#   '22800'],
#  ['0624660',
#   'Merced Union High School District',
#   '3640',
#   '2017',
#   '06',
#   '24660'],
#  ['0625150',
#   'Modesto City High School District',
#   '2762',
#   '2017',
#   '06',
#   '25150'],
#  ['0626310',
#   'Mountain View-Los Altos Union School District',
#   '245',
#   '2017',
#   '06',
#   '26310'],
#  ['0626880',
#   'Nevada Joint Union High School District',
#   '437',
#   '2017',
#   '06',
#   '26880'],
#  ['0629130',
#   'Oroville Union High School District',
#   '706',
#   '2017',
#   '06',
#   '29130'],
#  ['0629270',
#   'Oxnard Union High School District',
#   '2680',
#   '2017',
#   '06',
#   '29270'],
#  ['0630210',
#   'Perris Union High School District',
#   '1859',
#   '2017',
#   '06',
#   '30210'],
#  ['0630250',
#   'Petaluma Joint Union High School District',
#   '356',
#   '2017',
#   '06',
#   '30250'],
#  ['0630750',
#   'Placer Union High School District',
#   '352',
#   '2017',
#   '06',
#   '30750'],
#  ['0631230',
#   'Point Arena Joint Union High School District',
#   '43',
#   '2017',
#   '06',
#   '31230'],
#  ['0632010',
#   'Red Bluff Joint Union High School District',
#   '456',
#   '2017',
#   '06',
#   '32010'],
#  ['0633630',
#   'Roseville Joint Union High School District',
#   '629',
#   '2017',
#   '06',
#   '33630'],
#  ['0633980',
#   'Salinas Union High School District',
#   '2682',
#   '2017',
#   '06',
#   '33980'],
#  ['0634140', 'San Benito High School District', '371', '2017', '06', '34140'],
#  ['0634380',
#   'San Dieguito Union High School District',
#   '746',
#   '2017',
#   '06',
#   '34380'],
#  ['0634980',
#   'San Mateo Union High School District',
#   '568',
#   '2017',
#   '06',
#   '34980'],
#  ['0635110',
#   'San Rafael City High School District',
#   '318',
#   '2017',
#   '06',
#   '35110'],
#  ['0635600',
#   'Santa Cruz City High School District',
#   '696',
#   '2017',
#   '06',
#   '35600'],
#  ['0635670',
#   'Santa Maria Joint Union High School District',
#   '1563',
#   '2017',
#   '06',
#   '35670'],
#  ['0635830', 'Santa Rosa High School District', '1482', '2017', '06', '35830'],
#  ['0635850',
#   'Santa Ynez Valley Union High School District',
#   '58',
#   '2017',
#   '06',
#   '35850'],
#  ['0636390',
#   'Sequoia Union High School District',
#   '782',
#   '2017',
#   '06',
#   '36390'],
#  ['0636600',
#   'Shasta Union High School District',
#   '789',
#   '2017',
#   '06',
#   '36600'],
#  ['0636940',
#   'Siskiyou Union High School District',
#   '87',
#   '2017',
#   '06',
#   '36940'],
#  ['0636972',
#   'Victor Valley Union High School District',
#   '4819',
#   '2017',
#   '06',
#   '36972'],
#  ['0637260',
#   'Sonora Union High School District',
#   '193',
#   '2017',
#   '06',
#   '37260'],
#  ['0638280',
#   'Summerville Union High School District',
#   '31',
#   '2017',
#   '06',
#   '38280'],
#  ['0638610', 'Sutter Union High School District', '39', '2017', '06', '38610'],
#  ['0638640',
#   'Sweetwater Union High School District',
#   '7057',
#   '2017',
#   '06',
#   '38640'],
#  ['0638730', 'Taft Union High School District', '310', '2017', '06', '38730'],
#  ['0638790',
#   'Tamalpais Union High School District',
#   '227',
#   '2017',
#   '06',
#   '38790'],
#  ['0639930',
#   'Tulare Joint Union High School District',
#   '1365',
#   '2017',
#   '06',
#   '39930'],
#  ['0641430', 'Wasco Union High School District', '542', '2017', '06', '41430'],
#  ['0642350',
#   'Wheatland Union High School District',
#   '67',
#   '2017',
#   '06',
#   '42350'],
#  ['0642480',
#   'Whittier Union High School District',
#   '1590',
#   '2017',
#   '06',
#   '42480'],
#  ['0642510',
#   'William S. Hart Union High School District',
#   '1851',
#   '2017',
#   '06',
#   '42510'],
#  ['0643410', 'Yreka Union High School District', '141', '2017', '06', '43410'],
#  ['0900005', 'Regional High School District 19', '92', '2017', '09', '00005'],
#  ['0903570', 'Regional High School District 11', '31', '2017', '09', '03570'],
#  ['0903600', 'Regional High School District 01', '34', '2017', '09', '03600'],
#  ['0903630', 'Regional High School District 04', '48', '2017', '09', '03630'],
#  ['0903660', 'Regional High School District 05', '82', '2017', '09', '03660'],
#  ['0903720', 'Regional High School District 07', '40', '2017', '09', '03720'],
#  ['0903750', 'Regional High School District 08', '45', '2017', '09', '03750'],
#  ['0903780', 'Regional High School District 09', '31', '2017', '09', '03780'],
#  ['1701384',
#   'Illini West High School District 307',
#   '64',
#   '2017',
#   '17',
#   '01384'],
#  ['1703780',
#   'Anna Jonesboro Community High School District 81',
#   '141',
#   '2017',
#   '17',
#   '03780'],
#  ['1703870',
#   'Antioch Community High School District 117',
#   '140',
#   '2017',
#   '17',
#   '03870'],
#  ['1704020',
#   'Argo Community High School District 217',
#   '409',
#   '2017',
#   '17',
#   '04020'],
#  ['1704170',
#   'Township High School District 214',
#   '930',
#   '2017',
#   '17',
#   '04170'],
#  ['1704230',
#   'Armstrong Township High School District 225',
#   '21',
#   '2017',
#   '17',
#   '04230'],
#  ['1704770',
#   'Central Community High School District 71',
#   '42',
#   '2017',
#   '17',
#   '04770'],
#  ['1705640',
#   'Belleville Township High School District 201',
#   '786',
#   '2017',
#   '17',
#   '05640'],
#  ['1705970',
#   'Benton Consolidated High School District 103',
#   '147',
#   '2017',
#   '17',
#   '05970'],
#  ['1706420',
#   'Bloom Township High School District 206',
#   '1034',
#   '2017',
#   '17',
#   '06420'],
#  ['1706540',
#   'Community High School District 218',
#   '1014',
#   '2017',
#   '17',
#   '06540'],
#  ['1706960',
#   'Bradley-Bourbonnais Consolidated High School District 307',
#   '250',
#   '2017',
#   '17',
#   '06960'],
#  ['1707050',
#   'Bremen Community High School District 228',
#   '945',
#   '2017',
#   '17',
#   '07050'],
#  ['1708370',
#   'Carbondale Community High School District 165',
#   '383',
#   '2017',
#   '17',
#   '08370'],
#  ['1708400',
#   'Consolidated High School District 230',
#   '874',
#   '2017',
#   '17',
#   '08400'],
#  ['1709300',
#   'Centralia High School District 200',
#   '238',
#   '2017',
#   '17',
#   '09300'],
#  ['1709780',
#   'Chester Non-High School District 122',
#   '5',
#   '2017',
#   '17',
#   '09780'],
#  ['1711370',
#   'Community High School District 155',
#   '276',
#   '2017',
#   '17',
#   '11370'],
#  ['1712570',
#   'Community High School District 99',
#   '293',
#   '2017',
#   '17',
#   '12570'],
#  ['1712870',
#   'Dwight Township High School District 230',
#   '37',
#   '2017',
#   '17',
#   '12870'],
#  ['1712990',
#   'East Alton-Wood River Community High School District 14',
#   '139',
#   '2017',
#   '17',
#   '12990'],
#  ['1713230',
#   'East Peoria Community High School District 309',
#   '147',
#   '2017',
#   '17',
#   '13230'],
#  ['1713940', 'DuPage High School District 88', '404', '2017', '17', '13940'],
#  ['1714490',
#   'Evanston Township High School District 202',
#   '270',
#   '2017',
#   '17',
#   '14490'],
#  ['1714580',
#   'Evergreen Park Community High School District 231',
#   '88',
#   '2017',
#   '17',
#   '14580'],
#  ['1715030',
#   'Fenton Community High School District 100',
#   '152',
#   '2017',
#   '17',
#   '15030'],
#  ['1715840',
#   'Freeburg Community High School District 77',
#   '40',
#   '2017',
#   '17',
#   '15840'],
#  ['1716260',
#   'Gardner-South Wilmington Township High School District',
#   '15',
#   '2017',
#   '17',
#   '16260'],
#  ['1716830',
#   'Glenbard Township High School District 87',
#   '666',
#   '2017',
#   '17',
#   '16830'],
#  ['1717340',
#   'Grant Community High School District 124',
#   '124',
#   '2017',
#   '17',
#   '17340'],
#  ['1717550',
#   'Grayslake Community High School District 127',
#   '118',
#   '2017',
#   '17',
#   '17550'],
#  ['1718030', 'Hall High School District 502', '97', '2017', '17', '18030'],
#  ['1719080',
#   'Township High School District 113',
#   '149',
#   '2017',
#   '17',
#   '19080'],
#  ['1719320',
#   'Hinsdale Township High School District 86',
#   '253',
#   '2017',
#   '17',
#   '19320'],
#  ['1719560',
#   'Homewood-Flossmoor Community High School District 233',
#   '191',
#   '2017',
#   '17',
#   '19560'],
#  ['1719620',
#   'Hononegah Community High School District 207',
#   '98',
#   '2017',
#   '17',
#   '19620'],
#  ['1720610',
#   'Joliet Township High School District 204',
#   '905',
#   '2017',
#   '17',
#   '20610'],
#  ['1721780',
#   'Lake Forest Community High School District 115',
#   '48',
#   '2017',
#   '17',
#   '21780'],
#  ['1721840',
#   'Lake Park Community High School District 108',
#   '166',
#   '2017',
#   '17',
#   '21840'],
#  ['1722110',
#   'LaSalle-Peru Township High School District 120',
#   '207',
#   '2017',
#   '17',
#   '22110'],
#  ['1722500',
#   'Lemont Township High School District 210',
#   '120',
#   '2017',
#   '17',
#   '22500'],
#  ['1722740',
#   'Leyden Community High School District 212',
#   '440',
#   '2017',
#   '17',
#   '22740'],
#  ['1722830',
#   'Libertyville Community High School District 128',
#   '87',
#   '2017',
#   '17',
#   '22830'],
#  ['1722950',
#   'Limestone Community High School District 310',
#   '136',
#   '2017',
#   '17',
#   '22950'],
#  ['1723050',
#   'Lincoln Community High School District 404',
#   '125',
#   '2017',
#   '17',
#   '23050'],
#  ['1723070',
#   'Lincoln Way Community High School District 210',
#   '190',
#   '2017',
#   '17',
#   '23070'],
#  ['1723350',
#   'Lockport Township High School District 205',
#   '244',
#   '2017',
#   '17',
#   '23350'],
#  ['1723880',
#   'Lyons Township High School District 204',
#   '212',
#   '2017',
#   '17',
#   '23880'],
#  ['1724090',
#   'Maine Township High School District 207',
#   '632',
#   '2017',
#   '17',
#   '24090'],
#  ['1724570',
#   'Marengo Community High School District 154',
#   '57',
#   '2017',
#   '17',
#   '24570'],
#  ['1725320',
#   'McHenry Community High School District 156',
#   '181',
#   '2017',
#   '17',
#   '25320'],
#  ['1725650',
#   'Mendota Township High School District 280',
#   '91',
#   '2017',
#   '17',
#   '25650'],
#  ['1725770',
#   'Metamora Township High School District 122',
#   '41',
#   '2017',
#   '17',
#   '25770'],
#  ['1726180',
#   'Fairfield Community High School District 225',
#   '78',
#   '2017',
#   '17',
#   '26180'],
#  ['1726340',
#   'Minooka Community High School District 111',
#   '102',
#   '2017',
#   '17',
#   '26340'],
#  ['1726640',
#   'Morris Community High School District 101',
#   '86',
#   '2017',
#   '17',
#   '26640'],
#  ['1726880',
#   'J. Sterling Morton High School District 201',
#   '1651',
#   '2017',
#   '17',
#   '26880'],
#  ['1727360',
#   'Mount Vernon Township High School District 201',
#   '287',
#   '2017',
#   '17',
#   '27360'],
#  ['1727570',
#   'Mundelein Consolidated High School District 120',
#   '165',
#   '2017',
#   '17',
#   '27570'],
#  ['1727740',
#   'Nashville Community High School District 99',
#   '35',
#   '2017',
#   '17',
#   '27740'],
#  ['1728200',
#   'New Trier Township High School District 203',
#   '145',
#   '2017',
#   '17',
#   '28200'],
#  ['1728260',
#   'Newark Community High School District 18',
#   '14',
#   '2017',
#   '17',
#   '28260'],
#  ['1728530',
#   'Niles Township Community High School District 219',
#   '570',
#   '2017',
#   '17',
#   '28530'],
#  ['1729010',
#   'Northfield Township High School District 225',
#   '240',
#   '2017',
#   '17',
#   '29010'],
#  ['1729220',
#   'Oak Lawn Community High School District 229',
#   '319',
#   '2017',
#   '17',
#   '29220'],
#  ['1729280',
#   'Oak Park and River Forest District 200',
#   '139',
#   '2017',
#   '17',
#   '29280'],
#  ['1729730',
#   'Ohio Community High School District 505',
#   '3',
#   '2017',
#   '17',
#   '29730'],
#  ['1729790',
#   "O'Fallon Township High School District 203",
#   '196',
#   '2017',
#   '17',
#   '29790'],
#  ['1730330',
#   'Ottawa Township High School District 140',
#   '229',
#   '2017',
#   '17',
#   '30330'],
#  ['1730450',
#   'Township High School District 211',
#   '984',
#   '2017',
#   '17',
#   '30450'],
#  ['1731110',
#   'Pekin Community High School District 303',
#   '276',
#   '2017',
#   '17',
#   '31110'],
#  ['1731620',
#   'Pinckneyville Community High School District 101',
#   '56',
#   '2017',
#   '17',
#   '31620'],
#  ['1732220',
#   'Pontiac Township High School District 90',
#   '115',
#   '2017',
#   '17',
#   '32220'],
#  ['1732580',
#   'Adlai E. Stevenson High School District 125',
#   '119',
#   '2017',
#   '17',
#   '32580'],
#  ['1732700',
#   'Princeton High School District 500',
#   '68',
#   '2017',
#   '17',
#   '32700'],
#  ['1732910',
#   'Proviso Township High School District 209',
#   '1101',
#   '2017',
#   '17',
#   '32910'],
#  ['1733240',
#   'Rantoul Township High School District 193',
#   '201',
#   '2017',
#   '17',
#   '33240'],
#  ['1733270',
#   'Reavis Township High School District 220',
#   '334',
#   '2017',
#   '17',
#   '33270'],
#  ['1733420',
#   'Rich Township High School District 227',
#   '787',
#   '2017',
#   '17',
#   '33420'],
#  ['1733510',
#   'Richmond-Burton Community High School District 157',
#   '37',
#   '2017',
#   '17',
#   '33510'],
#  ['1733720',
#   'Ridgewood Community High School District 234',
#   '98',
#   '2017',
#   '17',
#   '33720'],
#  ['1734020',
#   'Riverside Brookfield Township School District 208',
#   '117',
#   '2017',
#   '17',
#   '34020'],
#  ['1734290',
#   'Rochelle Township High School District 212',
#   '111',
#   '2017',
#   '17',
#   '34290'],
#  ['1734380',
#   'Rock Falls Township High School District 301',
#   '135',
#   '2017',
#   '17',
#   '34380'],
#  ['1735190',
#   'Salem Community High School District 600',
#   '121',
#   '2017',
#   '17',
#   '35190'],
#  ['1735850',
#   'Seneca Township High School District 160',
#   '65',
#   '2017',
#   '17',
#   '35850'],
#  ['1737140',
#   'St. Anne Community High School District 302',
#   '49',
#   '2017',
#   '17',
#   '37140'],
#  ['1737410',
#   'St. Joseph-Ogden Community High School District 305',
#   '19',
#   '2017',
#   '17',
#   '37410'],
#  ['1738100',
#   'Streator Township High School District 40',
#   '211',
#   '2017',
#   '17',
#   '38100'],
#  ['1738940',
#   'Thornton Fractional Township High School District 215',
#   '785',
#   '2017',
#   '17',
#   '38940'],
#  ['1738970',
#   'Thornton Township High School District 205',
#   '1765',
#   '2017',
#   '17',
#   '38970'],
#  ['1739870',
#   'United Township High School District 30',
#   '313',
#   '2017',
#   '17',
#   '39870'],
#  ['1740290', 'Vienna High School District 133', '80', '2017', '17', '40290'],
#  ['1740440',
#   'Community High School District 94',
#   '259',
#   '2017',
#   '17',
#   '40440'],
#  ['1740800',
#   'Warren Township High School District 121',
#   '267',
#   '2017',
#   '17',
#   '40800'],
#  ['1740980',
#   'Washington Community High School District 308',
#   '71',
#   '2017',
#   '17',
#   '40980'],
#  ['1743890',
#   'Zion-Benton Township High School District 126',
#   '421',
#   '2017',
#   '17',
#   '43890'],
#  ['2300053',
#   'Five Town Community School District',
#   '45',
#   '2017',
#   '23',
#   '00053'],
#  ['2303480', 'Bremen', '3', '2017', '23', '03480'],
#  ['2304830', 'Damariscotta', '6', '2017', '23', '04830'],
#  ['2308400',
#   'Moosabec Community School District',
#   '15',
#   '2017',
#   '23',
#   '08400'],
#  ['2308500',
#   'Mount Desert Community School District',
#   '29',
#   '2017',
#   '23',
#   '08500'],
#  ['2308760', 'Newcastle', '3', '2017', '23', '08760'],
#  ['2500541', 'Somerset-Berkley School District', '73', '2017', '25', '00541'],
#  ['2501920', 'Amherst-Pelham School District', '205', '2017', '25', '01920'],
#  ['2502580', 'Berlin-Boylston School District', '17', '2017', '25', '02580'],
#  ['2503870', 'Concord-Carlisle School District', '37', '2017', '25', '03870'],
#  ['2504290', 'Dover-Sherborn School District', '61', '2017', '25', '04290'],
#  ['2504560', 'Nauset School District', '117', '2017', '25', '04560'],
#  ['2505100', 'Frontier School District', '41', '2017', '25', '05100'],
#  ['2505740', 'Hampshire School District', '40', '2017', '25', '05740'],
#  ['2506510', 'King Philip School District', '89', '2017', '25', '06510'],
#  ['2506930', 'Lincoln-Sudbury School District', '51', '2017', '25', '06930'],
#  ['2507380', "Martha's Vineyard School District", '48', '2017', '25', '07380'],
#  ['2507410', 'Masconomet School District', '51', '2017', '25', '07410'],
#  ['2508160', 'Mount Greylock School District', '70', '2017', '25', '08160'],
#  ['2508910',
#   'Northborough-Southborough School District',
#   '54',
#   '2017',
#   '25',
#   '08910'],
#  ['2509150', 'Old Rochester School District', '64', '2017', '25', '09150'],
#  ['2509900', 'Ralph C. Mahar School District', '98', '2017', '25', '09900'],
#  ['2510830', 'Silver Lake School District', '85', '2017', '25', '10830'],
#  ['2511490', 'Tantasqua School District', '97', '2017', '25', '11490'],
#  ['2525010',
#   'Fairhaven/New Bedford School Districts in Acushnet (9-12)',
#   '39',
#   '2017',
#   '25',
#   '25010'],
#  ['2525012',
#   'Nauset/Provincetown School Districts in Turo (7-12)',
#   '3',
#   '2017',
#   '25',
#   '25012'],
#  ['2525013',
#   'Mount Greylock/New Lebanon (NY) School Districts in Hancock (7-12)',
#   '7',
#   '2017',
#   '25',
#   '25013'],
#  ['2525015',
#   'Lee/Berkshire Hills in Farmington River Regional (7-12)',
#   '6',
#   '2017',
#   '25',
#   '25015'],
#  ['2727002',
#   'Clinton-Graceville-Beardsley-Wheaton-Sisseton/Wilmot (SD) in Browns Valley (9-12',
#   '3',
#   '2017',
#   '27',
#   '27002'],
#  ['2727003',
#   'Minneota-Ivanhoe Public School Districts in Ivanhoe (7-12)',
#   '7',
#   '2017',
#   '27',
#   '27003'],
#  ['2727004',
#   'Marshall-Minneota-RTR Public Schools in Lynd (9-12)',
#   '9',
#   '2017',
#   '27',
#   '27004'],
#  ['2727005',
#   'Marshall-Tracy Public Schools in Milroy (9-12)',
#   '3',
#   '2017',
#   '27',
#   '27005'],
#  ['2727006',
#   'Heron Lake-Okabena-Fulda-Worthington in Round Lake-Brewster (9-12)',
#   '11',
#   '2017',
#   '27',
#   '27006'],
#  ['2727007',
#   'St. Louis-Northland in Nett Lake (7-12)',
#   '13',
#   '2017',
#   '27',
#   '27007'],
#  ['2799001',
#   'Elkton School District 05-3 in Lake Benton (7-12)',
#   '13',
#   '2017',
#   '27',
#   '99001'],
#  ['3000095', 'Lame Deer High School District', '105', '2017', '30', '00095'],
#  ['3000097', 'North Star High School District', '10', '2017', '30', '00097'],
#  ['3000101',
#   'Chester-Joplin-Inverness High School District',
#   '30',
#   '2017',
#   '30',
#   '00101'],
#  ['3000933',
#   'Shields Valley High School District',
#   '12',
#   '2017',
#   '30',
#   '00933'],
#  ['3001740', 'Absarokee High School District', '4', '2017', '30', '01740'],
#  ['3002030', 'Anaconda High School District', '46', '2017', '30', '02030'],
#  ['3002250', 'Arlee High School District', '18', '2017', '30', '02250'],
#  ['3002450', 'Augusta High School District', '9', '2017', '30', '02450'],
#  ['3003090',
#   'Beaverhead County High School District',
#   '39',
#   '2017',
#   '30',
#   '03090'],
#  ['3003330', 'Belgrade High School District', '107', '2017', '30', '03330'],
#  ['3003450', 'Belt High School District', '23', '2017', '30', '03450'],
#  ['3003840', 'Bigfork High School District', '24', '2017', '30', '03840'],
#  ['3003900', 'Billings High School District', '543', '2017', '30', '03900'],
#  ['3004500', 'Box Elder High School District', '6', '2017', '30', '04500'],
#  ['3004590', 'Bozeman High School District', '131', '2017', '30', '04590'],
#  ['3004860',
#   'Powder River County High School District',
#   '13',
#   '2017',
#   '30',
#   '04860'],
#  ['3004920', 'Broadview High School District', '3', '2017', '30', '04920'],
#  ['3005040', 'Brockton High School District', '8', '2017', '30', '05040'],
#  ['3005190', 'Browning High School District', '143', '2017', '30', '05190'],
#  ['3005310', 'Butte High School District', '174', '2017', '30', '05310'],
#  ['3005610', 'Carter County High School District', '5', '2017', '30', '05610'],
#  ['3005910', 'Cascade High School District', '20', '2017', '30', '05910'],
#  ['3006115', 'Charlo High School District', '17', '2017', '30', '06115'],
#  ['3006270', 'Chinook High School District', '22', '2017', '30', '06270'],
#  ['3006330', 'Choteau High School District', '11', '2017', '30', '06330'],
#  ['3006810', 'Circle High School District', '27', '2017', '30', '06810'],
#  ['3007080', 'Colstrip High School District', '22', '2017', '30', '07080'],
#  ['3007140',
#   'Columbia Falls High School District',
#   '126',
#   '2017',
#   '30',
#   '07140'],
#  ['3007200', 'Columbus High School District', '26', '2017', '30', '07200'],
#  ['3007320', 'Conrad High School District', '38', '2017', '30', '07320'],
#  ['3007860', 'Culbertson High School District', '13', '2017', '30', '07860'],
#  ['3007930',
#   'Custer County High School District',
#   '59',
#   '2017',
#   '30',
#   '07930'],
#  ['3008190', 'Cut Bank High School District', '56', '2017', '30', '08190'],
#  ['3008340', 'Dawson High School District', '32', '2017', '30', '08340'],
#  ['3008850', 'Denton High School District', '3', '2017', '30', '08850'],
#  ['3009210', 'Drummond High School District', '4', '2017', '30', '09210'],
#  ['3010170', 'Fairfield High School District', '10', '2017', '30', '10170'],
#  ['3010290', 'Fairview High School District', '3', '2017', '30', '10290'],
#  ['3010530', 'Fergus High School District', '57', '2017', '30', '10530'],
#  ['3011190', 'Forsyth High School District', '11', '2017', '30', '11190'],
#  ['3011260', 'Fort Benton High School District', '5', '2017', '30', '11260'],
#  ['3011460', 'Frazer High School District', '26', '2017', '30', '11460'],
#  ['3011580', 'Froid High School District', '5', '2017', '30', '11580'],
#  ['3011850', 'Gardiner High School District', '10', '2017', '30', '11850'],
#  ['3011880',
#   'Garfield County High School District',
#   '10',
#   '2017',
#   '30',
#   '11880'],
#  ['3012300', 'Geyser High School District', '2', '2017', '30', '12300'],
#  ['3012990', 'Grass Range High School District', '7', '2017', '30', '12990'],
#  ['3013050', 'Great Falls High School District', '322', '2017', '30', '13050'],
#  ['3013340', 'Hardin High School District', '170', '2017', '30', '13340'],
#  ['3013360', 'Plenty Coups High School District', '21', '2017', '30', '13360'],
#  ['3013400', 'Harlem High School District', '48', '2017', '30', '13400'],
#  ['3013470', 'Harlowton High School District', '8', '2017', '30', '13470'],
#  ['3013590', 'Havre High School District', '110', '2017', '30', '13590'],
#  ['3013830', 'Helena High School District', '241', '2017', '30', '13830'],
#  ['3014370', 'Hinsdale High School District', '8', '2017', '30', '14370'],
#  ['3015120', 'Jefferson High School District', '22', '2017', '30', '15120'],
#  ['3015260', 'Joliet High School District', '13', '2017', '30', '15260'],
#  ['3015390', 'Judith Gap High School District', '3', '2017', '30', '15390'],
#  ['3015420', 'Flathead High School District', '323', '2017', '30', '15420'],
#  ['3016020', 'Lambert High School District', '2', '2017', '30', '16020'],
#  ['3016230', 'Laurel High School District', '43', '2017', '30', '16230'],
#  ['3016770',
#   'Lincoln County High School District',
#   '44',
#   '2017',
#   '30',
#   '16770'],
#  ['3017040', 'Lodge Grass High School District', '55', '2017', '30', '17040'],
#  ['3017640', 'Manhattan High School District', '11', '2017', '30', '17640'],
#  ['3018270', 'Melstone High School District', '2', '2017', '30', '18270'],
#  ['3018540', 'Missoula High School District', '522', '2017', '30', '18540'],
#  ['3018900', 'Moore High School District', '5', '2017', '30', '18900'],
#  ['3019500', 'Noxon High School District', '32', '2017', '30', '19500'],
#  ['3020070', 'Park City High School District', '8', '2017', '30', '20070'],
#  ['3020100', 'Park High School District', '55', '2017', '30', '20100'],
#  ['3021090', 'Polson High School District', '60', '2017', '30', '21090'],
#  ['3021270', 'Poplar High School District', '89', '2017', '30', '21270'],
#  ['3021450',
#   'Powell County High School District',
#   '39',
#   '2017',
#   '30',
#   '21450'],
#  ['3021540', 'Power High School District', '3', '2017', '30', '21540'],
#  ['3021900', 'Rapelje High School District', '1', '2017', '30', '21900'],
#  ['3022110', 'Red Lodge High School District', '44', '2017', '30', '22110'],
#  ['3022260', 'Reed Point High School District', '15', '2017', '30', '22260'],
#  ['3022410', 'Richey High School District', '1', '2017', '30', '22410'],
#  ['3022800', 'Ronan High School District', '93', '2017', '30', '22800'],
#  ['3023070', 'Roundup High School District', '42', '2017', '30', '23070'],
#  ['3023400', 'Saco High School District', '6', '2017', '30', '23400'],
#  ['3023550', 'Savage High School District', '16', '2017', '30', '23550'],
#  ['3023910', 'Shelby High School District', '20', '2017', '30', '23910'],
#  ['3023970', 'Shepherd High School District', '31', '2017', '30', '23970'],
#  ['3024180', 'Sheridan High School District', '7', '2017', '30', '24180'],
#  ['3024230', 'Sidney High School District', '32', '2017', '30', '24230'],
#  ['3024330', 'Simms High School District', '22', '2017', '30', '24330'],
#  ['3025050', 'Stevensville High School District', '53', '2017', '30', '25050'],
#  ['3025140', 'Centerville High School District', '4', '2017', '30', '25140'],
#  ['3025560',
#   'Sweet Grass County High School District',
#   '13',
#   '2017',
#   '30',
#   '25560'],
#  ['3026100',
#   'Thompson Falls High School District',
#   '54',
#   '2017',
#   '30',
#   '26100'],
#  ['3026190', 'Three Forks High School District', '5', '2017', '30', '26190'],
#  ['3026580', 'Troy High School District', '36', '2017', '30', '26580'],
#  ['3026670', 'Turner High School District', '3', '2017', '30', '26670'],
#  ['3027090', 'Valier High School District', '5', '2017', '30', '27090'],
#  ['3027790', 'Whitefish High School District', '44', '2017', '30', '27790'],
#  ['3027840', 'Whitehall High School District', '11', '2017', '30', '27840'],
#  ['3028170', 'Willow Creek High School District', '0', '2017', '30', '28170'],
#  ['3028620', 'Wolf Point High School District', '71', '2017', '30', '28620'],
#  ['3028911', 'Rocky Boy High School District', '61', '2017', '30', '28911'],
#  ['3300003',
#   'John Stark Regional School District',
#   '33',
#   '2017',
#   '33',
#   '00003'],
#  ['3300017',
#   'Exeter Regional Cooperative School District',
#   '97',
#   '2017',
#   '33',
#   '00017'],
#  ['3300049',
#   'Prospect Mountain High School Joint Maintenance Agreement District',
#   '29',
#   '2017',
#   '33',
#   '00049'],
#  ['3302670', 'Dresden School District', '80', '2017', '33', '02670'],
#  ['3303850',
#   'Hollis-Brookline Cooperative School District',
#   '30',
#   '2017',
#   '33',
#   '03850'],
#  ['3305830', 'Profile School District', '37', '2017', '33', '05830'],
#  ['3306260',
#   'Souhegan Cooperative School District',
#   '37',
#   '2017',
#   '33',
#   '06260'],
#  ['3307230',
#   'Winnacunnet Cooperative School District',
#   '78',
#   '2017',
#   '33',
#   '07230'],
#  ['3399965',
#   'Pemi-Baker Regional School District',
#   '56',
#   '2017',
#   '33',
#   '99965'],
#  ['3401770',
#   'Black Horse Pike Regional School District',
#   '545',
#   '2017',
#   '34',
#   '01770'],
#  ['3402800',
#   'Carlstadt-East Rutherford School District',
#   '42',
#   '2017',
#   '34',
#   '02800'],
#  ['3402880',
#   'Sterling High School School District',
#   '81',
#   '2017',
#   '34',
#   '02880'],
#  ['3402910', 'Central Regional School District', '313', '2017', '34', '02910'],
#  ['3403210',
#   'Clearview Regional School District',
#   '104',
#   '2017',
#   '34',
#   '03210'],
#  ['3403620',
#   'Cumberland Regional School District',
#   '314',
#   '2017',
#   '34',
#   '03620'],
#  ['3403750',
#   'Delaware Valley Regional School District',
#   '36',
#   '2017',
#   '34',
#   '03750'],
#  ['3404380',
#   'Eastern Camden County Regional School District',
#   '96',
#   '2017',
#   '34',
#   '04380'],
#  ['3405610',
#   'Freehold Regional School District',
#   '628',
#   '2017',
#   '34',
#   '05610'],
#  ['3405820', 'Gateway Regional School District', '71', '2017', '34', '05820'],
#  ['3406060',
#   'Greater Egg Harbor Regional School District',
#   '617',
#   '2017',
#   '34',
#   '06060'],
#  ['3406660',
#   'Hanover Park Regional School District',
#   '49',
#   '2017',
#   '34',
#   '06660'],
#  ['3407050',
#   'Henry Hudson Regional School District',
#   '38',
#   '2017',
#   '34',
#   '07050'],
#  ['3407140',
#   'High Point Regional School District',
#   '63',
#   '2017',
#   '34',
#   '07140'],
#  ['3407590',
#   'Hunterdon Central Regional School District',
#   '77',
#   '2017',
#   '34',
#   '07590'],
#  ['3407980',
#   'Kingsway Regional School District',
#   '112',
#   '2017',
#   '34',
#   '07980'],
#  ['3408060',
#   'Kittatinny Regional School District',
#   '67',
#   '2017',
#   '34',
#   '08060'],
#  ['3408190', 'Lakeland Regional School District', '61', '2017', '34', '08190'],
#  ['3408490', 'Lenape Regional School District', '269', '2017', '34', '08490'],
#  ['3408500',
#   'Lenape Valley Regional School District',
#   '66',
#   '2017',
#   '34',
#   '08500'],
#  ['3409090',
#   'Lower Cape May Regional School District',
#   '221',
#   '2017',
#   '34',
#   '09090'],
#  ['3409360',
#   'Mainland Regional School District',
#   '141',
#   '2017',
#   '34',
#   '09360'],
#  ['3409550',
#   'North Warren Regional School District',
#   '49',
#   '2017',
#   '34',
#   '09550'],
#  ['3410440',
#   'Monmouth Regional School District',
#   '110',
#   '2017',
#   '34',
#   '10440'],
#  ['3410740',
#   'Morris Hills Regional School District',
#   '133',
#   '2017',
#   '34',
#   '10740'],
#  ['3411610',
#   'North Hunterdon-Voorhees Regional School District',
#   '62',
#   '2017',
#   '34',
#   '11610'],
#  ['3411700',
#   'Northern Burlington Regional School District',
#   '65',
#   '2017',
#   '34',
#   '11700'],
#  ['3411730',
#   'Northern Highlands Regional School District',
#   '31',
#   '2017',
#   '34',
#   '11730'],
#  ['3411760',
#   'Northern Valley Regional School District',
#   '84',
#   '2017',
#   '34',
#   '11760'],
#  ['3412260',
#   'River Dell Regional School District',
#   '41',
#   '2017',
#   '34',
#   '12260'],
#  ['3412510',
#   'Pascack Valley Regional School District',
#   '52',
#   '2017',
#   '34',
#   '12510'],
#  ['3412570',
#   'Passaic Valley Regional School District',
#   '161',
#   '2017',
#   '34',
#   '12570'],
#  ['3412600',
#   'Passaic County Manchester Regional School District',
#   '226',
#   '2017',
#   '34',
#   '12600'],
#  ['3413000',
#   'Pinelands Regional School District',
#   '192',
#   '2017',
#   '34',
#   '13000'],
#  ['3413560',
#   'Ramapo-Indian Hill Regional School District',
#   '51',
#   '2017',
#   '34',
#   '13560'],
#  ['3413620',
#   'Rancocas Valley Regional School District',
#   '143',
#   '2017',
#   '34',
#   '13620'],
#  ['3413750',
#   'Red Bank Regional School District',
#   '107',
#   '2017',
#   '34',
#   '13750'],
#  ['3414400',
#   'Rumson-Fair Haven Regional School District',
#   '36',
#   '2017',
#   '34',
#   '14400'],
#  ['3414940', 'Shore Regional School District', '41', '2017', '34', '14940'],
#  ['3415450',
#   'Delsea Regional High School School District',
#   '119',
#   '2017',
#   '34',
#   '15450'],
#  ['3415480',
#   'Southern Regional School District',
#   '262',
#   '2017',
#   '34',
#   '15480'],
#  ['3416870',
#   'Wallkill Valley Regional School District',
#   '51',
#   '2017',
#   '34',
#   '16870'],
#  ['3416970',
#   'Warren Hills Regional School District',
#   '130',
#   '2017',
#   '34',
#   '16970'],
#  ['3417220',
#   'Watchung Hills Regional School District',
#   '54',
#   '2017',
#   '34',
#   '17220'],
#  ['3417460',
#   'West Essex Regional School District',
#   '63',
#   '2017',
#   '34',
#   '17460'],
#  ['3417550',
#   'West Morris Regional School District',
#   '53',
#   '2017',
#   '34',
#   '17550'],
#  ['3619020',
#   'Bellmore-Merrick Central High School District',
#   '178',
#   '2017',
#   '36',
#   '19020'],
#  ['3626520',
#   'Sewanhaka Central High School District',
#   '612',
#   '2017',
#   '36',
#   '26520'],
#  ['3629520',
#   'Valley Stream Central High School District',
#   '362',
#   '2017',
#   '36',
#   '29520'],
#  ['4040001',
#   'Secondary Coverage Area in White Oak Public Schools (9-12)',
#   '9',
#   '2017',
#   '40',
#   '40001'],
#  ['4103630',
#   'Harney County Union High School District 1J',
#   '15',
#   '2017',
#   '41',
#   '03630'],
#  ['4400420',
#   'Foster-Glocester Regional School District',
#   '82',
#   '2017',
#   '44',
#   '00420'],
#  ['5000006', 'Essex Community Education Center', '47', '2017', '50', '00006'],
#  ['5505490',
#   'Nicolet Union High School District',
#   '112',
#   '2017',
#   '55',
#   '05490'],
#  ['5506120',
#   'Hartford Union High School District',
#   '70',
#   '2017',
#   '55',
#   '06120'],
#  ['5506180',
#   'Arrowhead Union High School District',
#   '50',
#   '2017',
#   '55',
#   '06180'],
#  ['5507650',
#   'Lake Geneva-Genoa City Union High School District',
#   '168',
#   '2017',
#   '55',
#   '07650'],
#  ['5509630',
#   'Lakeland Union High School District',
#   '128',
#   '2017',
#   '55',
#   '09630'],
#  ['5513290',
#   'Westosha Central High School District',
#   '67',
#   '2017',
#   '55',
#   '13290'],
#  ['5515150',
#   'Union Grove Union High School District',
#   '38',
#   '2017',
#   '55',
#   '15150'],
#  ['5515480',
#   'Big Foot Union High School District',
#   '46',
#   '2017',
#   '55',
#   '15480'],
#  ['5515600',
#   'Waterford Union High School District',
#   '39',
#   '2017',
#   '55',
#   '15600'],
#  ['5516770', 'Wilmot Union High School District', '94', '2017', '55', '16770']]
