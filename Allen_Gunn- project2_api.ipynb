# %%
# dependencies
import pandas as pd 
import requests 
import json
from pprint import pprint 
# api keys
from api_keys import census

# %%
# url = "https://api.census.gov/data/timeseries/poverty/histpov2?get=PCTPOV&time=2017&RACE=1&GEO_ID=1"
# url = "https://api.census.gov/data/2017/acs/acs1?get=NAME,group(B01001)&for=us:1"
url="https://api.census.gov/data/timeseries/poverty/saipe/schdist?get=SD_NAME,SAEPOV5_17RV_PT&for=school+district+(Secondary)&YEAR=2017"
# Build query URL
query_url = url + "&key=" + census 

# Get poverty data
pov_response = requests.get(query_url)
pov_json = pov_response.json()

# # Get the temperature from the response
# print(f"The weather API responded with: {weather_json}.")

# %%
pov_response
# Out:
# <Response [200]>

# %%
pov_json
# Out:
# [['SD_NAME',
#   'SAEPOV5_17RV_PT',
#   'YEAR',
#   'state',
#   'school district (secondary)'],
#  ['Colorado River Union High School District', '580', '2017', '04', '00082'],
#  ['Agua Fria Union High School District', '868', '2017', '04', '00450'],
#  ['Antelope Union High School District', '72', '2017', '04', '00720'],
#  ['Bicentennial Union High School District', '45', '2017', '04', '01160'],
#  ['Buckeye Union High School District', '559', '2017', '04', '01410'],
#  ['Casa Grande Union High School District', '913', '2017', '04', '01740'],
#  ['Glendale Union High School District', '4880', '2017', '04', '03450'],
#  ['Mingus Union High School District', '307', '2017', '04', '05070'],
#  ['Patagonia Union High School District', '14', '2017', '04', '06030'],
#  ['Phoenix Union High School District', '12330', '2017', '04', '06330'],
#  ['Santa Cruz Valley Union High School District',
#   '160',
#   '2017',
#   '04',
#   '07530'],
#  ['Tempe Union High School District', '1567', '2017', '04', '08340'],
#  ['Tolleson Union High School District', '2238', '2017', '04', '08520'],
#  ['Valley Union High School District', '16', '2017', '04', '08910'],
#  ['Yuma Union High School District', '3123', '2017', '04', '09630'],
#  ['Acalanes Union High School District', '160', '2017', '06', '01650'],
#  ['Anaheim Union High School District', '7153', '2017', '06', '02630'],
#  ['West Sonoma County Union High School District',
#   '182',
#   '2017',
#   '06',
#   '02670'],
#  ['Anderson Union High School District', '435', '2017', '06', '02700'],
#  ['Antelope Valley Union Joint High School District',
#   '5272',
#   '2017',
#   '06',
#   '02820'],
#  ['Northern Humboldt Union High School District',
#   '302',
#   '2017',
#   '06',
#   '03030'],
#  ['Brawley Union High School District', '426', '2017', '06', '05820'],
#  ['Bret Harte Union High School District', '139', '2017', '06', '05940'],
#  ['Campbell Union High School District', '635', '2017', '06', '07230'],
#  ['Centinela Valley Union High School District',
#   '1870',
#   '2017',
#   '06',
#   '07920'],
#  ['Central Union High School District', '939', '2017', '06', '08010'],
#  ['Chaffey Joint Union High School District', '3471', '2017', '06', '08160'],
#  ['Chowchilla Union High School District', '308', '2017', '06', '08550'],
#  ['Corning Union High School District', '289', '2017', '06', '09810'],
#  ['Delano Joint Union High School District', '1435', '2017', '06', '10860'],
#  ['Dunsmuir Joint Union High School District', '24', '2017', '06', '11700'],
#  ['East Nicolaus Joint Union High School District',
#   '11',
#   '2017',
#   '06',
#   '11780'],
#  ['East Side Union High School District', '3075', '2017', '06', '11820'],
#  ['El Dorado Union High School District', '578', '2017', '06', '12070'],
#  ['El Monte Union High School District', '2248', '2017', '06', '12120'],
#  ['Escondido Union High School District', '1505', '2017', '06', '12910'],
#  ['Fallbrook Union High School District', '359', '2017', '06', '13530'],
#  ['Fortuna Union High School District', '203', '2017', '06', '14190'],
#  ['Fremont Union High School District', '423', '2017', '06', '14430'],
#  ['Fullerton Joint Union High School District', '2365', '2017', '06', '14760'],
#  ['Galt Joint Union High School District', '350', '2017', '06', '14820'],
#  ['Grossmont Union High School District', '3561', '2017', '06', '16230'],
#  ['Hanford Joint Union High School District', '863', '2017', '06', '16500'],
#  ['Huntington Beach Union High School District',
#   '2016',
#   '2017',
#   '06',
#   '18060'],
#  ['Jefferson Union High School District', '423', '2017', '06', '18930'],
#  ['Julian Union High School District', '38', '2017', '06', '19110'],
#  ['Kern High School District', '9501', '2017', '06', '19540'],
#  ['South Monterey County Joint Union High School District',
#   '468',
#   '2017',
#   '06',
#   '19650'],
#  ['Kingsburg Joint Union High School District', '289', '2017', '06', '19830'],
#  ['Lassen Union High School District', '130', '2017', '06', '21060'],
#  ['Le Grand Union High School District', '256', '2017', '06', '21270'],
#  ['Lemoore Union High School District', '415', '2017', '06', '21400'],
#  ['Liberty Union High School District', '533', '2017', '06', '21600'],
#  ['Los Gatos-Saratoga Joint Union School District',
#   '72',
#   '2017',
#   '06',
#   '22800'],
#  ['Merced Union High School District', '3640', '2017', '06', '24660'],
#  ['Modesto City High School District', '2762', '2017', '06', '25150'],
#  ['Mountain View-Los Altos Union School District',
#   '245',
#   '2017',
#   '06',
#   '26310'],
#  ['Nevada Joint Union High School District', '437', '2017', '06', '26880'],
#  ['Oroville Union High School District', '706', '2017', '06', '29130'],
#  ['Oxnard Union High School District', '2680', '2017', '06', '29270'],
#  ['Perris Union High School District', '1859', '2017', '06', '30210'],
#  ['Petaluma Joint Union High School District', '356', '2017', '06', '30250'],
#  ['Placer Union High School District', '352', '2017', '06', '30750'],
#  ['Point Arena Joint Union High School District', '43', '2017', '06', '31230'],
#  ['Red Bluff Joint Union High School District', '456', '2017', '06', '32010'],
#  ['Roseville Joint Union High School District', '629', '2017', '06', '33630'],
#  ['Salinas Union High School District', '2682', '2017', '06', '33980'],
#  ['San Benito High School District', '371', '2017', '06', '34140'],
#  ['San Dieguito Union High School District', '746', '2017', '06', '34380'],
#  ['San Mateo Union High School District', '568', '2017', '06', '34980'],
#  ['San Rafael City High School District', '318', '2017', '06', '35110'],
#  ['Santa Cruz City High School District', '696', '2017', '06', '35600'],
#  ['Santa Maria Joint Union High School District',
#   '1563',
#   '2017',
#   '06',
#   '35670'],
#  ['Santa Rosa High School District', '1482', '2017', '06', '35830'],
#  ['Santa Ynez Valley Union High School District', '58', '2017', '06', '35850'],
#  ['Sequoia Union High School District', '782', '2017', '06', '36390'],
#  ['Shasta Union High School District', '789', '2017', '06', '36600'],
#  ['Siskiyou Union High School District', '87', '2017', '06', '36940'],
#  ['Victor Valley Union High School District', '4819', '2017', '06', '36972'],
#  ['Sonora Union High School District', '193', '2017', '06', '37260'],
#  ['Summerville Union High School District', '31', '2017', '06', '38280'],
#  ['Sutter Union High School District', '39', '2017', '06', '38610'],
#  ['Sweetwater Union High School District', '7057', '2017', '06', '38640'],
#  ['Taft Union High School District', '310', '2017', '06', '38730'],
#  ['Tamalpais Union High School District', '227', '2017', '06', '38790'],
#  ['Tulare Joint Union High School District', '1365', '2017', '06', '39930'],
#  ['Wasco Union High School District', '542', '2017', '06', '41430'],
#  ['Wheatland Union High School District', '67', '2017', '06', '42350'],
#  ['Whittier Union High School District', '1590', '2017', '06', '42480'],
#  ['William S. Hart Union High School District', '1851', '2017', '06', '42510'],
#  ['Yreka Union High School District', '141', '2017', '06', '43410'],
#  ['Regional High School District 19', '92', '2017', '09', '00005'],
#  ['Regional High School District 11', '31', '2017', '09', '03570'],
#  ['Regional High School District 01', '34', '2017', '09', '03600'],
#  ['Regional High School District 04', '48', '2017', '09', '03630'],
#  ['Regional High School District 05', '82', '2017', '09', '03660'],
#  ['Regional High School District 07', '40', '2017', '09', '03720'],
#  ['Regional High School District 08', '45', '2017', '09', '03750'],
#  ['Regional High School District 09', '31', '2017', '09', '03780'],
#  ['Illini West High School District 307', '64', '2017', '17', '01384'],
#  ['Anna Jonesboro Community High School District 81',
#   '141',
#   '2017',
#   '17',
#   '03780'],
#  ['Antioch Community High School District 117', '140', '2017', '17', '03870'],
#  ['Argo Community High School District 217', '409', '2017', '17', '04020'],
#  ['Township High School District 214', '930', '2017', '17', '04170'],
#  ['Armstrong Township High School District 225', '21', '2017', '17', '04230'],
#  ['Central Community High School District 71', '42', '2017', '17', '04770'],
#  ['Belleville Township High School District 201',
#   '786',
#   '2017',
#   '17',
#   '05640'],
#  ['Benton Consolidated High School District 103',
#   '147',
#   '2017',
#   '17',
#   '05970'],
#  ['Bloom Township High School District 206', '1034', '2017', '17', '06420'],
#  ['Community High School District 218', '1014', '2017', '17', '06540'],
#  ['Bradley-Bourbonnais Consolidated High School District 307',
#   '250',
#   '2017',
#   '17',
#   '06960'],
#  ['Bremen Community High School District 228', '945', '2017', '17', '07050'],
#  ['Carbondale Community High School District 165',
#   '383',
#   '2017',
#   '17',
#   '08370'],
#  ['Consolidated High School District 230', '874', '2017', '17', '08400'],
#  ['Centralia High School District 200', '238', '2017', '17', '09300'],
#  ['Chester Non-High School District 122', '5', '2017', '17', '09780'],
#  ['Community High School District 155', '276', '2017', '17', '11370'],
#  ['Community High School District 99', '293', '2017', '17', '12570'],
#  ['Dwight Township High School District 230', '37', '2017', '17', '12870'],
#  ['East Alton-Wood River Community High School District 14',
#   '139',
#   '2017',
#   '17',
#   '12990'],
#  ['East Peoria Community High School District 309',
#   '147',
#   '2017',
#   '17',
#   '13230'],
#  ['DuPage High School District 88', '404', '2017', '17', '13940'],
#  ['Evanston Township High School District 202', '270', '2017', '17', '14490'],
#  ['Evergreen Park Community High School District 231',
#   '88',
#   '2017',
#   '17',
#   '14580'],
#  ['Fenton Community High School District 100', '152', '2017', '17', '15030'],
#  ['Freeburg Community High School District 77', '40', '2017', '17', '15840'],
#  ['Gardner-South Wilmington Township High School District',
#   '15',
#   '2017',
#   '17',
#   '16260'],
#  ['Glenbard Township High School District 87', '666', '2017', '17', '16830'],
#  ['Grant Community High School District 124', '124', '2017', '17', '17340'],
#  ['Grayslake Community High School District 127',
#   '118',
#   '2017',
#   '17',
#   '17550'],
#  ['Hall High School District 502', '97', '2017', '17', '18030'],
#  ['Township High School District 113', '149', '2017', '17', '19080'],
#  ['Hinsdale Township High School District 86', '253', '2017', '17', '19320'],
#  ['Homewood-Flossmoor Community High School District 233',
#   '191',
#   '2017',
#   '17',
#   '19560'],
#  ['Hononegah Community High School District 207', '98', '2017', '17', '19620'],
#  ['Joliet Township High School District 204', '905', '2017', '17', '20610'],
#  ['Lake Forest Community High School District 115',
#   '48',
#   '2017',
#   '17',
#   '21780'],
#  ['Lake Park Community High School District 108',
#   '166',
#   '2017',
#   '17',
#   '21840'],
#  ['LaSalle-Peru Township High School District 120',
#   '207',
#   '2017',
#   '17',
#   '22110'],
#  ['Lemont Township High School District 210', '120', '2017', '17', '22500'],
#  ['Leyden Community High School District 212', '440', '2017', '17', '22740'],
#  ['Libertyville Community High School District 128',
#   '87',
#   '2017',
#   '17',
#   '22830'],
#  ['Limestone Community High School District 310',
#   '136',
#   '2017',
#   '17',
#   '22950'],
#  ['Lincoln Community High School District 404', '125', '2017', '17', '23050'],
#  ['Lincoln Way Community High School District 210',
#   '190',
#   '2017',
#   '17',
#   '23070'],
#  ['Lockport Township High School District 205', '244', '2017', '17', '23350'],
#  ['Lyons Township High School District 204', '212', '2017', '17', '23880'],
#  ['Maine Township High School District 207', '632', '2017', '17', '24090'],
#  ['Marengo Community High School District 154', '57', '2017', '17', '24570'],
#  ['McHenry Community High School District 156', '181', '2017', '17', '25320'],
#  ['Mendota Township High School District 280', '91', '2017', '17', '25650'],
#  ['Metamora Township High School District 122', '41', '2017', '17', '25770'],
#  ['Fairfield Community High School District 225', '78', '2017', '17', '26180'],
#  ['Minooka Community High School District 111', '102', '2017', '17', '26340'],
#  ['Morris Community High School District 101', '86', '2017', '17', '26640'],
#  ['J. Sterling Morton High School District 201',
#   '1651',
#   '2017',
#   '17',
#   '26880'],
#  ['Mount Vernon Township High School District 201',
#   '287',
#   '2017',
#   '17',
#   '27360'],
#  ['Mundelein Consolidated High School District 120',
#   '165',
#   '2017',
#   '17',
#   '27570'],
#  ['Nashville Community High School District 99', '35', '2017', '17', '27740'],
#  ['New Trier Township High School District 203', '145', '2017', '17', '28200'],
#  ['Newark Community High School District 18', '14', '2017', '17', '28260'],
#  ['Niles Township Community High School District 219',
#   '570',
#   '2017',
#   '17',
#   '28530'],
#  ['Northfield Township High School District 225',
#   '240',
#   '2017',
#   '17',
#   '29010'],
#  ['Oak Lawn Community High School District 229', '319', '2017', '17', '29220'],
#  ['Oak Park and River Forest District 200', '139', '2017', '17', '29280'],
#  ['Ohio Community High School District 505', '3', '2017', '17', '29730'],
#  ["O'Fallon Township High School District 203", '196', '2017', '17', '29790'],
#  ['Ottawa Township High School District 140', '229', '2017', '17', '30330'],
#  ['Township High School District 211', '984', '2017', '17', '30450'],
#  ['Pekin Community High School District 303', '276', '2017', '17', '31110'],
#  ['Pinckneyville Community High School District 101',
#   '56',
#   '2017',
#   '17',
#   '31620'],
#  ['Pontiac Township High School District 90', '115', '2017', '17', '32220'],
#  ['Adlai E. Stevenson High School District 125', '119', '2017', '17', '32580'],
#  ['Princeton High School District 500', '68', '2017', '17', '32700'],
#  ['Proviso Township High School District 209', '1101', '2017', '17', '32910'],
#  ['Rantoul Township High School District 193', '201', '2017', '17', '33240'],
#  ['Reavis Township High School District 220', '334', '2017', '17', '33270'],
#  ['Rich Township High School District 227', '787', '2017', '17', '33420'],
#  ['Richmond-Burton Community High School District 157',
#   '37',
#   '2017',
#   '17',
#   '33510'],
#  ['Ridgewood Community High School District 234', '98', '2017', '17', '33720'],
#  ['Riverside Brookfield Township School District 208',
#   '117',
#   '2017',
#   '17',
#   '34020'],
#  ['Rochelle Township High School District 212', '111', '2017', '17', '34290'],
#  ['Rock Falls Township High School District 301',
#   '135',
#   '2017',
#   '17',
#   '34380'],
#  ['Salem Community High School District 600', '121', '2017', '17', '35190'],
#  ['Seneca Township High School District 160', '65', '2017', '17', '35850'],
#  ['St. Anne Community High School District 302', '49', '2017', '17', '37140'],
#  ['St. Joseph-Ogden Community High School District 305',
#   '19',
#   '2017',
#   '17',
#   '37410'],
#  ['Streator Township High School District 40', '211', '2017', '17', '38100'],
#  ['Thornton Fractional Township High School District 215',
#   '785',
#   '2017',
#   '17',
#   '38940'],
#  ['Thornton Township High School District 205', '1765', '2017', '17', '38970'],
#  ['United Township High School District 30', '313', '2017', '17', '39870'],
#  ['Vienna High School District 133', '80', '2017', '17', '40290'],
#  ['Community High School District 94', '259', '2017', '17', '40440'],
#  ['Warren Township High School District 121', '267', '2017', '17', '40800'],
#  ['Washington Community High School District 308',
#   '71',
#   '2017',
#   '17',
#   '40980'],
#  ['Zion-Benton Township High School District 126',
#   '421',
#   '2017',
#   '17',
#   '43890'],
#  ['Five Town Community School District', '45', '2017', '23', '00053'],
#  ['Bremen', '3', '2017', '23', '03480'],
#  ['Damariscotta', '6', '2017', '23', '04830'],
#  ['Moosabec Community School District', '15', '2017', '23', '08400'],
#  ['Mount Desert Community School District', '29', '2017', '23', '08500'],
#  ['Newcastle', '3', '2017', '23', '08760'],
#  ['Somerset-Berkley School District', '73', '2017', '25', '00541'],
#  ['Amherst-Pelham School District', '205', '2017', '25', '01920'],
#  ['Berlin-Boylston School District', '17', '2017', '25', '02580'],
#  ['Concord-Carlisle School District', '37', '2017', '25', '03870'],
#  ['Dover-Sherborn School District', '61', '2017', '25', '04290'],
#  ['Nauset School District', '117', '2017', '25', '04560'],
#  ['Frontier School District', '41', '2017', '25', '05100'],
#  ['Hampshire School District', '40', '2017', '25', '05740'],
#  ['King Philip School District', '89', '2017', '25', '06510'],
#  ['Lincoln-Sudbury School District', '51', '2017', '25', '06930'],
#  ["Martha's Vineyard School District", '48', '2017', '25', '07380'],
#  ['Masconomet School District', '51', '2017', '25', '07410'],
#  ['Mount Greylock School District', '70', '2017', '25', '08160'],
#  ['Northborough-Southborough School District', '54', '2017', '25', '08910'],
#  ['Old Rochester School District', '64', '2017', '25', '09150'],
#  ['Ralph C. Mahar School District', '98', '2017', '25', '09900'],
#  ['Silver Lake School District', '85', '2017', '25', '10830'],
#  ['Tantasqua School District', '97', '2017', '25', '11490'],
#  ['Fairhaven/New Bedford School Districts in Acushnet (9-12)',
#   '39',
#   '2017',
#   '25',
#   '25010'],
#  ['Nauset/Provincetown School Districts in Turo (7-12)',
#   '3',
#   '2017',
#   '25',
#   '25012'],
#  ['Mount Greylock/New Lebanon (NY) School Districts in Hancock (7-12)',
#   '7',
#   '2017',
#   '25',
#   '25013'],
#  ['Lee/Berkshire Hills in Farmington River Regional (7-12)',
#   '6',
#   '2017',
#   '25',
#   '25015'],
#  ['Clinton-Graceville-Beardsley-Wheaton-Sisseton/Wilmot (SD) in Browns Valley (9-12',
#   '3',
#   '2017',
#   '27',
#   '27002'],
#  ['Minneota-Ivanhoe Public School Districts in Ivanhoe (7-12)',
#   '7',
#   '2017',
#   '27',
#   '27003'],
#  ['Marshall-Minneota-RTR Public Schools in Lynd (9-12)',
#   '9',
#   '2017',
#   '27',
#   '27004'],
#  ['Marshall-Tracy Public Schools in Milroy (9-12)',
#   '3',
#   '2017',
#   '27',
#   '27005'],
#  ['Heron Lake-Okabena-Fulda-Worthington in Round Lake-Brewster (9-12)',
#   '11',
#   '2017',
#   '27',
#   '27006'],
#  ['St. Louis-Northland in Nett Lake (7-12)', '13', '2017', '27', '27007'],
#  ['Elkton School District 05-3 in Lake Benton (7-12)',
#   '13',
#   '2017',
#   '27',
#   '99001'],
#  ['Lame Deer High School District', '105', '2017', '30', '00095'],
#  ['North Star High School District', '10', '2017', '30', '00097'],
#  ['Chester-Joplin-Inverness High School District',
#   '30',
#   '2017',
#   '30',
#   '00101'],
#  ['Shields Valley High School District', '12', '2017', '30', '00933'],
#  ['Absarokee High School District', '4', '2017', '30', '01740'],
#  ['Anaconda High School District', '46', '2017', '30', '02030'],
#  ['Arlee High School District', '18', '2017', '30', '02250'],
#  ['Augusta High School District', '9', '2017', '30', '02450'],
#  ['Beaverhead County High School District', '39', '2017', '30', '03090'],
#  ['Belgrade High School District', '107', '2017', '30', '03330'],
#  ['Belt High School District', '23', '2017', '30', '03450'],
#  ['Bigfork High School District', '24', '2017', '30', '03840'],
#  ['Billings High School District', '543', '2017', '30', '03900'],
#  ['Box Elder High School District', '6', '2017', '30', '04500'],
#  ['Bozeman High School District', '131', '2017', '30', '04590'],
#  ['Powder River County High School District', '13', '2017', '30', '04860'],
#  ['Broadview High School District', '3', '2017', '30', '04920'],
#  ['Brockton High School District', '8', '2017', '30', '05040'],
#  ['Browning High School District', '143', '2017', '30', '05190'],
#  ['Butte High School District', '174', '2017', '30', '05310'],
#  ['Carter County High School District', '5', '2017', '30', '05610'],
#  ['Cascade High School District', '20', '2017', '30', '05910'],
#  ['Charlo High School District', '17', '2017', '30', '06115'],
#  ['Chinook High School District', '22', '2017', '30', '06270'],
#  ['Choteau High School District', '11', '2017', '30', '06330'],
#  ['Circle High School District', '27', '2017', '30', '06810'],
#  ['Colstrip High School District', '22', '2017', '30', '07080'],
#  ['Columbia Falls High School District', '126', '2017', '30', '07140'],
#  ['Columbus High School District', '26', '2017', '30', '07200'],
#  ['Conrad High School District', '38', '2017', '30', '07320'],
#  ['Culbertson High School District', '13', '2017', '30', '07860'],
#  ['Custer County High School District', '59', '2017', '30', '07930'],
#  ['Cut Bank High School District', '56', '2017', '30', '08190'],
#  ['Dawson High School District', '32', '2017', '30', '08340'],
#  ['Denton High School District', '3', '2017', '30', '08850'],
#  ['Drummond High School District', '4', '2017', '30', '09210'],
#  ['Fairfield High School District', '10', '2017', '30', '10170'],
#  ['Fairview High School District', '3', '2017', '30', '10290'],
#  ['Fergus High School District', '57', '2017', '30', '10530'],
#  ['Forsyth High School District', '11', '2017', '30', '11190'],
#  ['Fort Benton High School District', '5', '2017', '30', '11260'],
#  ['Frazer High School District', '26', '2017', '30', '11460'],
#  ['Froid High School District', '5', '2017', '30', '11580'],
#  ['Gardiner High School District', '10', '2017', '30', '11850'],
#  ['Garfield County High School District', '10', '2017', '30', '11880'],
#  ['Geyser High School District', '2', '2017', '30', '12300'],
#  ['Grass Range High School District', '7', '2017', '30', '12990'],
#  ['Great Falls High School District', '322', '2017', '30', '13050'],
#  ['Hardin High School District', '170', '2017', '30', '13340'],
#  ['Plenty Coups High School District', '21', '2017', '30', '13360'],
#  ['Harlem High School District', '48', '2017', '30', '13400'],
#  ['Harlowton High School District', '8', '2017', '30', '13470'],
#  ['Havre High School District', '110', '2017', '30', '13590'],
#  ['Helena High School District', '241', '2017', '30', '13830'],
#  ['Hinsdale High School District', '8', '2017', '30', '14370'],
#  ['Jefferson High School District', '22', '2017', '30', '15120'],
#  ['Joliet High School District', '13', '2017', '30', '15260'],
#  ['Judith Gap High School District', '3', '2017', '30', '15390'],
#  ['Flathead High School District', '323', '2017', '30', '15420'],
#  ['Lambert High School District', '2', '2017', '30', '16020'],
#  ['Laurel High School District', '43', '2017', '30', '16230'],
#  ['Lincoln County High School District', '44', '2017', '30', '16770'],
#  ['Lodge Grass High School District', '55', '2017', '30', '17040'],
#  ['Manhattan High School District', '11', '2017', '30', '17640'],
#  ['Melstone High School District', '2', '2017', '30', '18270'],
#  ['Missoula High School District', '522', '2017', '30', '18540'],
#  ['Moore High School District', '5', '2017', '30', '18900'],
#  ['Noxon High School District', '32', '2017', '30', '19500'],
#  ['Park City High School District', '8', '2017', '30', '20070'],
#  ['Park High School District', '55', '2017', '30', '20100'],
#  ['Polson High School District', '60', '2017', '30', '21090'],
#  ['Poplar High School District', '89', '2017', '30', '21270'],
#  ['Powell County High School District', '39', '2017', '30', '21450'],
#  ['Power High School District', '3', '2017', '30', '21540'],
#  ['Rapelje High School District', '1', '2017', '30', '21900'],
#  ['Red Lodge High School District', '44', '2017', '30', '22110'],
#  ['Reed Point High School District', '15', '2017', '30', '22260'],
#  ['Richey High School District', '1', '2017', '30', '22410'],
#  ['Ronan High School District', '93', '2017', '30', '22800'],
#  ['Roundup High School District', '42', '2017', '30', '23070'],
#  ['Saco High School District', '6', '2017', '30', '23400'],
#  ['Savage High School District', '16', '2017', '30', '23550'],
#  ['Shelby High School District', '20', '2017', '30', '23910'],
#  ['Shepherd High School District', '31', '2017', '30', '23970'],
#  ['Sheridan High School District', '7', '2017', '30', '24180'],
#  ['Sidney High School District', '32', '2017', '30', '24230'],
#  ['Simms High School District', '22', '2017', '30', '24330'],
#  ['Stevensville High School District', '53', '2017', '30', '25050'],
#  ['Centerville High School District', '4', '2017', '30', '25140'],
#  ['Sweet Grass County High School District', '13', '2017', '30', '25560'],
#  ['Thompson Falls High School District', '54', '2017', '30', '26100'],
#  ['Three Forks High School District', '5', '2017', '30', '26190'],
#  ['Troy High School District', '36', '2017', '30', '26580'],
#  ['Turner High School District', '3', '2017', '30', '26670'],
#  ['Valier High School District', '5', '2017', '30', '27090'],
#  ['Whitefish High School District', '44', '2017', '30', '27790'],
#  ['Whitehall High School District', '11', '2017', '30', '27840'],
#  ['Willow Creek High School District', '0', '2017', '30', '28170'],
#  ['Wolf Point High School District', '71', '2017', '30', '28620'],
#  ['Rocky Boy High School District', '61', '2017', '30', '28911'],
#  ['John Stark Regional School District', '33', '2017', '33', '00003'],
#  ['Exeter Regional Cooperative School District', '97', '2017', '33', '00017'],
#  ['Prospect Mountain High School Joint Maintenance Agreement District',
#   '29',
#   '2017',
#   '33',
#   '00049'],
#  ['Dresden School District', '80', '2017', '33', '02670'],
#  ['Hollis-Brookline Cooperative School District', '30', '2017', '33', '03850'],
#  ['Profile School District', '37', '2017', '33', '05830'],
#  ['Souhegan Cooperative School District', '37', '2017', '33', '06260'],
#  ['Winnacunnet Cooperative School District', '78', '2017', '33', '07230'],
#  ['Pemi-Baker Regional School District', '56', '2017', '33', '99965'],
#  ['Black Horse Pike Regional School District', '545', '2017', '34', '01770'],
#  ['Carlstadt-East Rutherford School District', '42', '2017', '34', '02800'],
#  ['Sterling High School School District', '81', '2017', '34', '02880'],
#  ['Central Regional School District', '313', '2017', '34', '02910'],
#  ['Clearview Regional School District', '104', '2017', '34', '03210'],
#  ['Cumberland Regional School District', '314', '2017', '34', '03620'],
#  ['Delaware Valley Regional School District', '36', '2017', '34', '03750'],
#  ['Eastern Camden County Regional School District',
#   '96',
#   '2017',
#   '34',
#   '04380'],
#  ['Freehold Regional School District', '628', '2017', '34', '05610'],
#  ['Gateway Regional School District', '71', '2017', '34', '05820'],
#  ['Greater Egg Harbor Regional School District', '617', '2017', '34', '06060'],
#  ['Hanover Park Regional School District', '49', '2017', '34', '06660'],
#  ['Henry Hudson Regional School District', '38', '2017', '34', '07050'],
#  ['High Point Regional School District', '63', '2017', '34', '07140'],
#  ['Hunterdon Central Regional School District', '77', '2017', '34', '07590'],
#  ['Kingsway Regional School District', '112', '2017', '34', '07980'],
#  ['Kittatinny Regional School District', '67', '2017', '34', '08060'],
#  ['Lakeland Regional School District', '61', '2017', '34', '08190'],
#  ['Lenape Regional School District', '269', '2017', '34', '08490'],
#  ['Lenape Valley Regional School District', '66', '2017', '34', '08500'],
#  ['Lower Cape May Regional School District', '221', '2017', '34', '09090'],
#  ['Mainland Regional School District', '141', '2017', '34', '09360'],
#  ['North Warren Regional School District', '49', '2017', '34', '09550'],
#  ['Monmouth Regional School District', '110', '2017', '34', '10440'],
#  ['Morris Hills Regional School District', '133', '2017', '34', '10740'],
#  ['North Hunterdon-Voorhees Regional School District',
#   '62',
#   '2017',
#   '34',
#   '11610'],
#  ['Northern Burlington Regional School District', '65', '2017', '34', '11700'],
#  ['Northern Highlands Regional School District', '31', '2017', '34', '11730'],
#  ['Northern Valley Regional School District', '84', '2017', '34', '11760'],
#  ['River Dell Regional School District', '41', '2017', '34', '12260'],
#  ['Pascack Valley Regional School District', '52', '2017', '34', '12510'],
#  ['Passaic Valley Regional School District', '161', '2017', '34', '12570'],
#  ['Passaic County Manchester Regional School District',
#   '226',
#   '2017',
#   '34',
#   '12600'],
#  ['Pinelands Regional School District', '192', '2017', '34', '13000'],
#  ['Ramapo-Indian Hill Regional School District', '51', '2017', '34', '13560'],
#  ['Rancocas Valley Regional School District', '143', '2017', '34', '13620'],
#  ['Red Bank Regional School District', '107', '2017', '34', '13750'],
#  ['Rumson-Fair Haven Regional School District', '36', '2017', '34', '14400'],
#  ['Shore Regional School District', '41', '2017', '34', '14940'],
#  ['Delsea Regional High School School District', '119', '2017', '34', '15450'],
#  ['Southern Regional School District', '262', '2017', '34', '15480'],
#  ['Wallkill Valley Regional School District', '51', '2017', '34', '16870'],
#  ['Warren Hills Regional School District', '130', '2017', '34', '16970'],
#  ['Watchung Hills Regional School District', '54', '2017', '34', '17220'],
#  ['West Essex Regional School District', '63', '2017', '34', '17460'],
#  ['West Morris Regional School District', '53', '2017', '34', '17550'],
#  ['Bellmore-Merrick Central High School District',
#   '178',
#   '2017',
#   '36',
#   '19020'],
#  ['Sewanhaka Central High School District', '612', '2017', '36', '26520'],
#  ['Valley Stream Central High School District', '362', '2017', '36', '29520'],
#  ['Secondary Coverage Area in White Oak Public Schools (9-12)',
#   '9',
#   '2017',
#   '40',
#   '40001'],
#  ['Harney County Union High School District 1J', '15', '2017', '41', '03630'],
#  ['Foster-Glocester Regional School District', '82', '2017', '44', '00420'],
#  ['Essex Community Education Center', '47', '2017', '50', '00006'],
#  ['Nicolet Union High School District', '112', '2017', '55', '05490'],
#  ['Hartford Union High School District', '70', '2017', '55', '06120'],
#  ['Arrowhead Union High School District', '50', '2017', '55', '06180'],
#  ['Lake Geneva-Genoa City Union High School District',
#   '168',
#   '2017',
#   '55',
#   '07650'],
#  ['Lakeland Union High School District', '128', '2017', '55', '09630'],
#  ['Westosha Central High School District', '67', '2017', '55', '13290'],
#  ['Union Grove Union High School District', '38', '2017', '55', '15150'],
#  ['Big Foot Union High School District', '46', '2017', '55', '15480'],
#  ['Waterford Union High School District', '39', '2017', '55', '15600'],
#  ['Wilmot Union High School District', '94', '2017', '55', '16770']]
