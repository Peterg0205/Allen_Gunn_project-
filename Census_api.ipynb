# %%
# dependencies
import pandas as pd 
import requests 
import us
import json
from pprint import pprint 
# api keys
from api_keys import census

# %%
# Built URL using Census variables website https://api.census.gov/data/timeseries/poverty/saipe/variables.html
url="https://api.census.gov/data/timeseries/poverty/saipe/schdist?get=GEOID,SD_NAME,SAEPOV5_17RV_PT&for=school+district+(Secondary)&YEAR=2017"

# Build query URL
query_url = url + "&key=" + census 

# Get poverty data
pov_response = requests.get(query_url)
pov_json = pov_response.json()

# %%
pov_response
# Out:
# <Response [200]>

# %%
pov_json[0]
# Out:
# ['GEOID',
#  'SD_NAME',
#  'SAEPOV5_17RV_PT',
#  'YEAR',
#  'state',
#  'school district (secondary)']

# %%
pov_df=pd.DataFrame(columns=pov_json[0], data=pov_json)
pov_df
# Out:
#        GEOID                                    SD_NAME  SAEPOV5_17RV_PT  \
# 0      GEOID                                    SD_NAME  SAEPOV5_17RV_PT
# 1    0400082  Colorado River Union High School District              580
# 2    0400450       Agua Fria Union High School District              868
# 3    0400720        Antelope Union High School District               72
# 4    0401160    Bicentennial Union High School District               45
# ..       ...                                        ...              ...
# 399  5513290      Westosha Central High School District               67
# 400  5515150     Union Grove Union High School District               38
# 401  5515480        Big Foot Union High School District               46
# 402  5515600       Waterford Union High School District               39
# 403  5516770          Wilmot Union High School District               94
#
#      YEAR  state  school district (secondary)
# 0    YEAR  state  school district (secondary)
# 1    2017     04                        00082
# 2    2017     04                        00450
# 3    2017     04                        00720
# 4    2017     04                        01160
# ..    ...    ...                          ...
# 399  2017     55                        13290
# 400  2017     55                        15150
# 401  2017     55                        15480
# 402  2017     55                        15600
# 403  2017     55                        16770
#
# [404 rows x 6 columns]

# %%
# Drop first row
pov_df.drop(index=pov_df.index[0], axis=0,inplace=True)

# %%
# Reset the index
pov_df.reset_index(inplace=True, drop=True)
pov_df
# Out:
#        GEOID                                  SD_NAME SAEPOV5_17RV_PT  YEAR  \
# 0    0400450     Agua Fria Union High School District             868  2017
# 1    0400720      Antelope Union High School District              72  2017
# 2    0401160  Bicentennial Union High School District              45  2017
# 3    0401410       Buckeye Union High School District             559  2017
# 4    0401740   Casa Grande Union High School District             913  2017
# ..       ...                                      ...             ...   ...
# 397  5513290    Westosha Central High School District              67  2017
# 398  5515150   Union Grove Union High School District              38  2017
# 399  5515480      Big Foot Union High School District              46  2017
# 400  5515600     Waterford Union High School District              39  2017
# 401  5516770        Wilmot Union High School District              94  2017
#
#     state school district (secondary)      State
# 0      04                       00450    Arizona
# 1      04                       00720    Arizona
# 2      04                       01160    Arizona
# 3      04                       01410    Arizona
# 4      04                       01740    Arizona
# ..    ...                         ...        ...
# 397    55                       13290  Wisconsin
# 398    55                       15150  Wisconsin
# 399    55                       15480  Wisconsin
# 400    55                       15600  Wisconsin
# 401    55                       16770  Wisconsin
#
# [402 rows x 7 columns]

# %%
# Change state fips codes to State name
fips_to_name = us.states.mapping("fips", "name")
pov_df["State"] = pov_df["state"].map(fips_to_name)
pov_df
# Out:
#        GEOID                                  SD_NAME SAEPOV5_17RV_PT  YEAR  \
# 0    0400450     Agua Fria Union High School District             868  2017
# 1    0400720      Antelope Union High School District              72  2017
# 2    0401160  Bicentennial Union High School District              45  2017
# 3    0401410       Buckeye Union High School District             559  2017
# 4    0401740   Casa Grande Union High School District             913  2017
# ..       ...                                      ...             ...   ...
# 397  5513290    Westosha Central High School District              67  2017
# 398  5515150   Union Grove Union High School District              38  2017
# 399  5515480      Big Foot Union High School District              46  2017
# 400  5515600     Waterford Union High School District              39  2017
# 401  5516770        Wilmot Union High School District              94  2017
#
#     state school district (secondary)      State
# 0      04                       00450    Arizona
# 1      04                       00720    Arizona
# 2      04                       01160    Arizona
# 3      04                       01410    Arizona
# 4      04                       01740    Arizona
# ..    ...                         ...        ...
# 397    55                       13290  Wisconsin
# 398    55                       15150  Wisconsin
# 399    55                       15480  Wisconsin
# 400    55                       15600  Wisconsin
# 401    55                       16770  Wisconsin
#
# [402 rows x 7 columns]

# %%
# Change state fips codes to State Abbreviation so that this can match the other dataset if needed
fips_to_name = us.states.mapping("fips", "abbr")
pov_df["State Abbr"] = pov_df["state"].map(fips_to_name)
pov_df
# Out:
#        GEOID                                  SD_NAME SAEPOV5_17RV_PT  YEAR  \
# 0    0400450     Agua Fria Union High School District             868  2017
# 1    0400720      Antelope Union High School District              72  2017
# 2    0401160  Bicentennial Union High School District              45  2017
# 3    0401410       Buckeye Union High School District             559  2017
# 4    0401740   Casa Grande Union High School District             913  2017
# ..       ...                                      ...             ...   ...
# 397  5513290    Westosha Central High School District              67  2017
# 398  5515150   Union Grove Union High School District              38  2017
# 399  5515480      Big Foot Union High School District              46  2017
# 400  5515600     Waterford Union High School District              39  2017
# 401  5516770        Wilmot Union High School District              94  2017
#
#     state school district (secondary)      State State Abbr
# 0      04                       00450    Arizona         AZ
# 1      04                       00720    Arizona         AZ
# 2      04                       01160    Arizona         AZ
# 3      04                       01410    Arizona         AZ
# 4      04                       01740    Arizona         AZ
# ..    ...                         ...        ...        ...
# 397    55                       13290  Wisconsin         WI
# 398    55                       15150  Wisconsin         WI
# 399    55                       15480  Wisconsin         WI
# 400    55                       15600  Wisconsin         WI
# 401    55                       16770  Wisconsin         WI
#
# [402 rows x 8 columns]

# %%
# Rename state colomn to be State Fips code
pov_df.rename(columns={'state':'State Fips'}, inplace = True)
# Rename Census data code to appropriate name
pov_df.rename(columns={'SAEPOV5_17RV_PT':'Ages 5-17 in Families in Poverty, Count Est'}, inplace = True)
# Rename SD to School District Name
pov_df.rename(columns={'SD_NAME':'School Dist Name'}, inplace = True)
# Rename school district (secondary) to School District Code
pov_df.rename(columns={'school district (secondary)':'School Dist Code'}, inplace = True)
# Reorder columns 
pov_df=pov_df[['GEOID','State Fips','State','State Abbr','School Dist Code','School Dist Name','Ages 5-17 in Families in Poverty, Count Est','YEAR']]
pov_df
# Out:
#        GEOID State Fips      State State Abbr School Dist Code  \
# 0    0400450         04    Arizona         AZ            00450
# 1    0400720         04    Arizona         AZ            00720
# 2    0401160         04    Arizona         AZ            01160
# 3    0401410         04    Arizona         AZ            01410
# 4    0401740         04    Arizona         AZ            01740
# ..       ...        ...        ...        ...              ...
# 397  5513290         55  Wisconsin         WI            13290
# 398  5515150         55  Wisconsin         WI            15150
# 399  5515480         55  Wisconsin         WI            15480
# 400  5515600         55  Wisconsin         WI            15600
# 401  5516770         55  Wisconsin         WI            16770
#
#                             School Dist Name  \
# 0       Agua Fria Union High School District
# 1        Antelope Union High School District
# 2    Bicentennial Union High School District
# 3         Buckeye Union High School District
# 4     Casa Grande Union High School District
# ..                                       ...
# 397    Westosha Central High School District
# 398   Union Grove Union High School District
# 399      Big Foot Union High School District
# 400     Waterford Union High School District
# 401        Wilmot Union High School District
#
#     Ages 5-17 in Families in Poverty, Count Est  YEAR
# 0                                           868  2017
# 1                                            72  2017
# 2                                            45  2017
# 3                                           559  2017
# 4                                           913  2017
# ..                                          ...   ...
# 397                                          67  2017
# 398                                          38  2017
# 399                                          46  2017
# 400                                          39  2017
# 401                                          94  2017
#
# [402 rows x 8 columns]

# %%
# drop duplicates if any
pov_df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#        GEOID State Fips      State State Abbr School Dist Code  \
# 0    0400450         04    Arizona         AZ            00450
# 1    0400720         04    Arizona         AZ            00720
# 2    0401160         04    Arizona         AZ            01160
# 3    0401410         04    Arizona         AZ            01410
# 4    0401740         04    Arizona         AZ            01740
# ..       ...        ...        ...        ...              ...
# 397  5513290         55  Wisconsin         WI            13290
# 398  5515150         55  Wisconsin         WI            15150
# 399  5515480         55  Wisconsin         WI            15480
# 400  5515600         55  Wisconsin         WI            15600
# 401  5516770         55  Wisconsin         WI            16770
#
#                             School Dist Name  \
# 0       Agua Fria Union High School District
# 1        Antelope Union High School District
# 2    Bicentennial Union High School District
# 3         Buckeye Union High School District
# 4     Casa Grande Union High School District
# ..                                       ...
# 397    Westosha Central High School District
# 398   Union Grove Union High School District
# 399      Big Foot Union High School District
# 400     Waterford Union High School District
# 401        Wilmot Union High School District
#
#     Ages 5-17 in Families in Poverty, Count Est  YEAR
# 0                                           868  2017
# 1                                            72  2017
# 2                                            45  2017
# 3                                           559  2017
# 4                                           913  2017
# ..                                          ...   ...
# 397                                          67  2017
# 398                                          38  2017
# 399                                          46  2017
# 400                                          39  2017
# 401                                          94  2017
#
# [402 rows x 8 columns]

# %%
# drop null values if any
pov_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#        GEOID State Fips      State State Abbr School Dist Code  \
# 0    0400450         04    Arizona         AZ            00450
# 1    0400720         04    Arizona         AZ            00720
# 2    0401160         04    Arizona         AZ            01160
# 3    0401410         04    Arizona         AZ            01410
# 4    0401740         04    Arizona         AZ            01740
# ..       ...        ...        ...        ...              ...
# 397  5513290         55  Wisconsin         WI            13290
# 398  5515150         55  Wisconsin         WI            15150
# 399  5515480         55  Wisconsin         WI            15480
# 400  5515600         55  Wisconsin         WI            15600
# 401  5516770         55  Wisconsin         WI            16770
#
#                             School Dist Name  \
# 0       Agua Fria Union High School District
# 1        Antelope Union High School District
# 2    Bicentennial Union High School District
# 3         Buckeye Union High School District
# 4     Casa Grande Union High School District
# ..                                       ...
# 397    Westosha Central High School District
# 398   Union Grove Union High School District
# 399      Big Foot Union High School District
# 400     Waterford Union High School District
# 401        Wilmot Union High School District
#
#     Ages 5-17 in Families in Poverty, Count Est  YEAR
# 0                                           868  2017
# 1                                            72  2017
# 2                                            45  2017
# 3                                           559  2017
# 4                                           913  2017
# ..                                          ...   ...
# 397                                          67  2017
# 398                                          38  2017
# 399                                          46  2017
# 400                                          39  2017
# 401                                          94  2017
#
# [402 rows x 8 columns]

# %%
pov_df.sample(100)
# Out:
#        GEOID State Fips       State State Abbr School Dist Code  \
# 400  5515600         55   Wisconsin         WI            15600
# 356  3408190         34  New Jersey         NJ            08190
# 369  3412510         34  New Jersey         NJ            12510
# 195  2300053         23       Maine         ME            00053
# 371  3412600         34  New Jersey         NJ            12600
# ..       ...        ...         ...        ...              ...
# 31   0611820         06  California         CA            11820
# 8    0406330         04     Arizona         AZ            06330
# 249  3005310         30     Montana         MT            05310
# 154  1726880         17    Illinois         IL            26880
# 250  3005610         30     Montana         MT            05610
#
#                                       School Dist Name  \
# 400               Waterford Union High School District
# 356                  Lakeland Regional School District
# 369            Pascack Valley Regional School District
# 195                Five Town Community School District
# 371  Passaic County Manchester Regional School Dist...
# ..                                                 ...
# 31                East Side Union High School District
# 8                   Phoenix Union High School District
# 249                         Butte High School District
# 154        J. Sterling Morton High School District 201
# 250                 Carter County High School District
#
#     Ages 5-17 in Families in Poverty, Count Est  YEAR
# 400                                          39  2017
# 356                                          61  2017
# 369                                          52  2017
# 195                                          45  2017
# 371                                         226  2017
# ..                                          ...   ...
# 31                                         3075  2017
# 8                                         12330  2017
# 249                                         174  2017
# 154                                        1651  2017
# 250                                           5  2017
#
# [100 rows x 8 columns]

# %%
# Reset the index
pov_df.reset_index(inplace=True, drop=True)
pov_df
# Out:
#        GEOID State Fips      State State Abbr School Dist Code  \
# 0    0400450         04    Arizona         AZ            00450
# 1    0400720         04    Arizona         AZ            00720
# 2    0401160         04    Arizona         AZ            01160
# 3    0401410         04    Arizona         AZ            01410
# 4    0401740         04    Arizona         AZ            01740
# ..       ...        ...        ...        ...              ...
# 397  5513290         55  Wisconsin         WI            13290
# 398  5515150         55  Wisconsin         WI            15150
# 399  5515480         55  Wisconsin         WI            15480
# 400  5515600         55  Wisconsin         WI            15600
# 401  5516770         55  Wisconsin         WI            16770
#
#                             School Dist Name  \
# 0       Agua Fria Union High School District
# 1        Antelope Union High School District
# 2    Bicentennial Union High School District
# 3         Buckeye Union High School District
# 4     Casa Grande Union High School District
# ..                                       ...
# 397    Westosha Central High School District
# 398   Union Grove Union High School District
# 399      Big Foot Union High School District
# 400     Waterford Union High School District
# 401        Wilmot Union High School District
#
#     Ages 5-17 in Families in Poverty, Count Est  YEAR
# 0                                           868  2017
# 1                                            72  2017
# 2                                            45  2017
# 3                                           559  2017
# 4                                           913  2017
# ..                                          ...   ...
# 397                                          67  2017
# 398                                          38  2017
# 399                                          46  2017
# 400                                          39  2017
# 401                                          94  2017
#
# [402 rows x 8 columns]

# %%
# Save to csv
pov_df.to_csv("School_Poverty_data2017.csv",index=False, header=True)
