# %%
import pandas as pd 
from sqlalchemy import create_engine
import requests
import json

# %%
clean_data = "Resources/Obesity Overweight and Weight Control Final Clean.csv"
clean_data
# Out:
# 'Resources/Obesity Overweight and Weight Control Final Clean.csv'

# %%
clean_data_df = pd.read_csv("Obesity Overweight and Weight Control Final Clean.csv")

# %%
clean_data_df.head(5)
# Out:
#    Unnamed: 0  YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 0          21  1999           MM  Miami-Dade County, FL       Weight loss
# 1          30  2005           RI           Rhode Island       Weight loss
# 2          46  2011           KY               Kentucky       Weight loss
# 3          64  2007           LA              Louisiana       Weight loss
# 4          69  2009           TX                  Texas       Weight loss
#
#             Greater_Risk_Question  Greater_Risk_Data_Value  \
# 0  Were not trying to lose weight                  83.7466
# 1  Were not trying to lose weight                  46.8113
# 2  Were not trying to lose weight                  57.3838
# 3  Were not trying to lose weight                  71.1292
# 4  Were not trying to lose weight                  59.4503
#
#    Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 0                            74.6253                             90.0273
# ...

# %%
dropna_data = clean_data_df.dropna()
dropna_data.head(5)
# Out:
#    Unnamed: 0  YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 0          21  1999           MM  Miami-Dade County, FL       Weight loss
# 1          30  2005           RI           Rhode Island       Weight loss
# 2          46  2011           KY               Kentucky       Weight loss
# 3          64  2007           LA              Louisiana       Weight loss
# 4          69  2009           TX                  Texas       Weight loss
#
#             Greater_Risk_Question  Greater_Risk_Data_Value  \
# 0  Were not trying to lose weight                  83.7466
# 1  Were not trying to lose weight                  46.8113
# 2  Were not trying to lose weight                  57.3838
# 3  Were not trying to lose weight                  71.1292
# 4  Were not trying to lose weight                  59.4503
#
#    Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 0                            74.6253                             90.0273
# ...

# %%
dropna_data
# Out:
#        Unnamed: 0  YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 0              21  1999           MM  Miami-Dade County, FL       Weight loss
# 1              30  2005           RI           Rhode Island       Weight loss
# 2              46  2011           KY               Kentucky       Weight loss
# 3              64  2007           LA              Louisiana       Weight loss
# 4              69  2009           TX                  Texas       Weight loss
# ...           ...   ...          ...                    ...               ...
# 24060      315679  2001           AL                Alabama       Weight loss
# 24061      315698  2011           MD               Maryland       Weight loss
# 24062      315700  2015           WY                Wyoming       Weight loss
# 24063      315709  1995           FT     Broward County, FL       Weight loss
# 24064      315714  2011           OK               Oklahoma       Weight loss
#
# ...

# %%
copy_df = dropna_data.copy()

# %%
copy_df.sample(100, replace = True)
copy_df
# Out:
#        Unnamed: 0  YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 0              21  1999           MM  Miami-Dade County, FL       Weight loss
# 1              30  2005           RI           Rhode Island       Weight loss
# 2              46  2011           KY               Kentucky       Weight loss
# 3              64  2007           LA              Louisiana       Weight loss
# 4              69  2009           TX                  Texas       Weight loss
# ...           ...   ...          ...                    ...               ...
# 24060      315679  2001           AL                Alabama       Weight loss
# 24061      315698  2011           MD               Maryland       Weight loss
# 24062      315700  2015           WY                Wyoming       Weight loss
# 24063      315709  1995           FT     Broward County, FL       Weight loss
# 24064      315714  2011           OK               Oklahoma       Weight loss
#
# ...

# %%
copy_df.drop_duplicates(subset=None,keep='first', inplace= False, ignore_index= False)
# Out:
#        Unnamed: 0  YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 0              21  1999           MM  Miami-Dade County, FL       Weight loss
# 1              30  2005           RI           Rhode Island       Weight loss
# 2              46  2011           KY               Kentucky       Weight loss
# 3              64  2007           LA              Louisiana       Weight loss
# 4              69  2009           TX                  Texas       Weight loss
# ...           ...   ...          ...                    ...               ...
# 24060      315679  2001           AL                Alabama       Weight loss
# 24061      315698  2011           MD               Maryland       Weight loss
# 24062      315700  2015           WY                Wyoming       Weight loss
# 24063      315709  1995           FT     Broward County, FL       Weight loss
# 24064      315714  2011           OK               Oklahoma       Weight loss
#
# ...

# %%
new_copy_df= copy_df.sample(100)
new_copy_df
# Out:
#        Unnamed: 0  YEAR LocationAbbr   LocationDesc ShortQuestionText  \
# 21734      284859  1999           SD   South Dakota       Weight loss
# 4615        60218  1999           VT        Vermont       Weight loss
# 1824        24503  2005           WI      Wisconsin       Weight loss
# 9282       121372  2001           SA  San Diego, CA       Weight loss
# 4405        57340  2017           NE       Nebraska       Weight loss
# ...           ...   ...          ...            ...               ...
# 10756      140900  2003           DA     Dallas, TX       Weight loss
# 9632       125970  2007           NV         Nevada       Weight loss
# 10186      133430  2015           MS    Mississippi       Weight loss
# 12796      168123  2003           WV  West Virginia       Weight loss
# 2501        32923  2007           LA      Louisiana       Weight loss
#
#                 Greater_Risk_Question  Greater_Risk_Data_Value  \
# ...

# %%
# Reset the index
new_copy_df.reset_index(inplace=True, drop=True)
new_copy_df
# Out:
#     Unnamed: 0  YEAR LocationAbbr   LocationDesc ShortQuestionText  \
# 0       284859  1999           SD   South Dakota       Weight loss
# 1        60218  1999           VT        Vermont       Weight loss
# 2        24503  2005           WI      Wisconsin       Weight loss
# 3       121372  2001           SA  San Diego, CA       Weight loss
# 4        57340  2017           NE       Nebraska       Weight loss
# ..         ...   ...          ...            ...               ...
# 95      140900  2003           DA     Dallas, TX       Weight loss
# 96      125970  2007           NV         Nevada       Weight loss
# 97      133430  2015           MS    Mississippi       Weight loss
# 98      168123  2003           WV  West Virginia       Weight loss
# 99       32923  2007           LA      Louisiana       Weight loss
#
#              Greater_Risk_Question  Greater_Risk_Data_Value  \
# 0   Were not trying to lose weight                  72.4688
# ...

# %%
new_copy_df.to_csv('Obesity Overweight and Weight Control Final Clean.csv')
