# %%
import pandas as pd 
from sqlalchemy import create_engine
import requests
import json

# %%
clean_data = "Resources/Obesity Overweight and Weight Control Final Clean.csv"
clean_data
# Out:
# 'Resources/Obesity Overweight and Weight Control Final Clean.csv'

# %%
clean_data_df = pd.read_csv("Obesity Overweight and Weight Control Final Clean.csv")

# %%
clean_data_df.head(5)
# Out:
#    YEAR LocationAbbr        LocationDesc     ShortQuestionText  \
# 0  2017           FT  Broward County, FL            Overweight
# 1  2007           HI              Hawaii               Obesity
# 2  1999           VT             Vermont  Perception of weight
# 3  2005           PR         Puerto Rico           Weight loss
# 4  2011           ND        North Dakota               Obesity
#
#                                Greater_Risk_Question  Greater_Risk_Data_Value  \
# 0                                    Were overweight                      NaN
# 1                                        Had obesity                  12.0560
# 2  Described themselves as slightly or very overw...                  37.4113
# 3                     Were not trying to lose weight                      NaN
# 4                                        Had obesity                      NaN
#
#    Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 0                                NaN                                 NaN
# 1                             8.9089                             16.1182
# 2                            34.2417                             40.6927
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#          Lesser_Risk_Question  Lesser_Risk_Data_Value  \
# 0                         NaN                     NaN
# 1                         NaN                 87.9440
# 2                         NaN                 62.5887
# 3  Were trying to lose weight                     NaN
# 4                         NaN                     NaN
#
#    Lesser_Risk_Low_Confidence_Limit  Lesser_Risk_High_Confidence_Limit  \
# 0                               NaN                                NaN
# 1                           83.8818                            91.0911
# 2                           59.3073                            65.7583
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   Sample_Size     Sex                       Race  Grade  \
# 0           5    Male                      Asian   11th
# 1         398   Total                      Asian  Total
# 2         875  Female                      White    9th
# 3           1    Male              Multiple Race   10th
# 4           2    Male  Black or African American   12th
#
#                                  GeoLocation  LocationId StratificationType
# 0                    (26.190096, -80.365865)       106.0              Local
# 1  (21.304850435000446, -157.85774940299973)        15.0              State
# 2    (43.62538123900049, -72.51764079099962)        50.0              State
# 3                    (18.220833, -66.590149)        72.0          Territory
# 4   (47.47531977900047, -100.11842104899966)        38.0              State

# %%
dropna_data = clean_data_df.dropna()
dropna_data.head(5)
# Out:
#     YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 21  1999           MM  Miami-Dade County, FL       Weight loss
# 30  2005           RI           Rhode Island       Weight loss
# 46  2011           KY               Kentucky       Weight loss
# 64  2007           LA              Louisiana       Weight loss
# 69  2009           TX                  Texas       Weight loss
#
#              Greater_Risk_Question  Greater_Risk_Data_Value  \
# 21  Were not trying to lose weight                  83.7466
# 30  Were not trying to lose weight                  46.8113
# 46  Were not trying to lose weight                  57.3838
# 64  Were not trying to lose weight                  71.1292
# 69  Were not trying to lose weight                  59.4503
#
#     Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 21                            74.6253                             90.0273
# 30                            38.6592                             55.1372
# 46                            48.8880                             65.4651
# 64                            59.7947                             80.3200
# 69                            53.8738                             64.7931
#
#           Lesser_Risk_Question  Lesser_Risk_Data_Value  \
# 21  Were trying to lose weight                 16.2534
# 30  Were trying to lose weight                 53.1887
# 46  Were trying to lose weight                 42.6162
# 64  Were trying to lose weight                 28.8708
# 69  Were trying to lose weight                 40.5497
#
#     Lesser_Risk_Low_Confidence_Limit  Lesser_Risk_High_Confidence_Limit  \
# 21                            9.9727                            25.3747
# 30                           44.8628                            61.3408
# 46                           34.5349                            51.1120
# 64                           19.6800                            40.2053
# 69                           35.2069                            46.1262
#
#    Sample_Size     Sex                       Race  Grade  \
# 21         123    Male  Black or African American    9th
# 30         100  Female         Hispanic or Latino    9th
# 46         150   Total  Black or African American  Total
# 64         200    Male  Black or African American  Total
# 69         626    Male         Hispanic or Latino  Total
#
#                                  GeoLocation  LocationId StratificationType
# 21                   (25.551603, -80.632692)       108.0              Local
# 30   (41.70828019300046, -71.52247031399963)        44.0              State
# 46  (37.645970271000465, -84.77497104799966)        21.0              State
# 64   (31.31266064400046, -92.44568007099969)        22.0              State
# 69  (31.827240407000488, -99.42677020599967)        48.0              State

# %%
dropna_data
# Out:
#         YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 21      1999           MM  Miami-Dade County, FL       Weight loss
# 30      2005           RI           Rhode Island       Weight loss
# 46      2011           KY               Kentucky       Weight loss
# 64      2007           LA              Louisiana       Weight loss
# 69      2009           TX                  Texas       Weight loss
# ...      ...          ...                    ...               ...
# 315679  2001           AL                Alabama       Weight loss
# 315698  2011           MD               Maryland       Weight loss
# 315700  2015           WY                Wyoming       Weight loss
# 315709  1995           FT     Broward County, FL       Weight loss
# 315714  2011           OK               Oklahoma       Weight loss
#
#                  Greater_Risk_Question  Greater_Risk_Data_Value  \
# 21      Were not trying to lose weight                  83.7466
# 30      Were not trying to lose weight                  46.8113
# 46      Were not trying to lose weight                  57.3838
# 64      Were not trying to lose weight                  71.1292
# 69      Were not trying to lose weight                  59.4503
# ...                                ...                      ...
# 315679  Were not trying to lose weight                  77.3953
# 315698  Were not trying to lose weight                  58.3476
# 315700  Were not trying to lose weight                  60.8925
# 315709  Were not trying to lose weight                  35.2309
# 315714  Were not trying to lose weight                  53.5417
#
#         Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 21                                74.6253                             90.0273
# 30                                38.6592                             55.1372
# 46                                48.8880                             65.4651
# 64                                59.7947                             80.3200
# 69                                53.8738                             64.7931
# ...                                   ...                                 ...
# 315679                            67.3788                             85.0200
# 315698                            50.8871                             65.4443
# 315700                            56.9041                             64.7406
# 315709                            30.2751                             40.5263
# 315714                            44.0264                             62.8060
#
#               Lesser_Risk_Question  Lesser_Risk_Data_Value  \
# 21      Were trying to lose weight                 16.2534
# 30      Were trying to lose weight                 53.1887
# 46      Were trying to lose weight                 42.6162
# 64      Were trying to lose weight                 28.8708
# 69      Were trying to lose weight                 40.5497
# ...                            ...                     ...
# 315679  Were trying to lose weight                 22.6047
# 315698  Were trying to lose weight                 41.6524
# 315700  Were trying to lose weight                 39.1075
# 315709  Were trying to lose weight                 64.7691
# 315714  Were trying to lose weight                 46.4583
#
#         Lesser_Risk_Low_Confidence_Limit  Lesser_Risk_High_Confidence_Limit  \
# 21                                9.9727                            25.3747
# 30                               44.8628                            61.3408
# 46                               34.5349                            51.1120
# 64                               19.6800                            40.2053
# 69                               35.2069                            46.1262
# ...                                  ...                                ...
# 315679                           14.9800                            32.6212
# 315698                           34.5557                            49.1129
# 315700                           35.2594                            43.0959
# 315709                           59.4737                            69.7249
# 315714                           37.1940                            55.9736
#
#        Sample_Size     Sex                       Race  Grade  \
# 21             123    Male  Black or African American    9th
# 30             100  Female         Hispanic or Latino    9th
# 46             150   Total  Black or African American  Total
# 64             200    Male  Black or African American  Total
# 69             626    Male         Hispanic or Latino  Total
# ...            ...     ...                        ...    ...
# 315679         153    Male                      Total   11th
# 315698         340   Total  Black or African American   10th
# 315700         521   Total                      White   10th
# 315709         402  Female                      White  Total
# 315714         160   Total                      White   10th
#
#                                      GeoLocation  LocationId  \
# 21                       (25.551603, -80.632692)       108.0
# 30       (41.70828019300046, -71.52247031399963)        44.0
# 46      (37.645970271000465, -84.77497104799966)        21.0
# 64       (31.31266064400046, -92.44568007099969)        22.0
# 69      (31.827240407000488, -99.42677020599967)        48.0
# ...                                          ...         ...
# 315679   (32.84057112200048, -86.63186076199969)         1.0
# 315698   (39.29058096400047, -76.60926011099963)        24.0
# 315700  (43.23554134300048, -108.10983035299967)        56.0
# 315709                   (26.190096, -80.365865)       106.0
# 315714   (35.47203135600046, -97.52107021399968)        40.0
#
#        StratificationType
# 21                  Local
# 30                  State
# 46                  State
# 64                  State
# 69                  State
# ...                   ...
# 315679              State
# 315698              State
# 315700              State
# 315709              Local
# 315714              State
#
# [24065 rows x 19 columns]

# %%
copy_df = dropna_data.copy()

# %%
copy_df.sample(100, replace = True)
copy_df
# Out:
#         YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 21      1999           MM  Miami-Dade County, FL       Weight loss
# 30      2005           RI           Rhode Island       Weight loss
# 46      2011           KY               Kentucky       Weight loss
# 64      2007           LA              Louisiana       Weight loss
# 69      2009           TX                  Texas       Weight loss
# ...      ...          ...                    ...               ...
# 315679  2001           AL                Alabama       Weight loss
# 315698  2011           MD               Maryland       Weight loss
# 315700  2015           WY                Wyoming       Weight loss
# 315709  1995           FT     Broward County, FL       Weight loss
# 315714  2011           OK               Oklahoma       Weight loss
#
#                  Greater_Risk_Question  Greater_Risk_Data_Value  \
# 21      Were not trying to lose weight                  83.7466
# 30      Were not trying to lose weight                  46.8113
# 46      Were not trying to lose weight                  57.3838
# 64      Were not trying to lose weight                  71.1292
# 69      Were not trying to lose weight                  59.4503
# ...                                ...                      ...
# 315679  Were not trying to lose weight                  77.3953
# 315698  Were not trying to lose weight                  58.3476
# 315700  Were not trying to lose weight                  60.8925
# 315709  Were not trying to lose weight                  35.2309
# 315714  Were not trying to lose weight                  53.5417
#
#         Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 21                                74.6253                             90.0273
# 30                                38.6592                             55.1372
# 46                                48.8880                             65.4651
# 64                                59.7947                             80.3200
# 69                                53.8738                             64.7931
# ...                                   ...                                 ...
# 315679                            67.3788                             85.0200
# 315698                            50.8871                             65.4443
# 315700                            56.9041                             64.7406
# 315709                            30.2751                             40.5263
# 315714                            44.0264                             62.8060
#
#               Lesser_Risk_Question  Lesser_Risk_Data_Value  \
# 21      Were trying to lose weight                 16.2534
# 30      Were trying to lose weight                 53.1887
# 46      Were trying to lose weight                 42.6162
# 64      Were trying to lose weight                 28.8708
# 69      Were trying to lose weight                 40.5497
# ...                            ...                     ...
# 315679  Were trying to lose weight                 22.6047
# 315698  Were trying to lose weight                 41.6524
# 315700  Were trying to lose weight                 39.1075
# 315709  Were trying to lose weight                 64.7691
# 315714  Were trying to lose weight                 46.4583
#
#         Lesser_Risk_Low_Confidence_Limit  Lesser_Risk_High_Confidence_Limit  \
# 21                                9.9727                            25.3747
# 30                               44.8628                            61.3408
# 46                               34.5349                            51.1120
# 64                               19.6800                            40.2053
# 69                               35.2069                            46.1262
# ...                                  ...                                ...
# 315679                           14.9800                            32.6212
# 315698                           34.5557                            49.1129
# 315700                           35.2594                            43.0959
# 315709                           59.4737                            69.7249
# 315714                           37.1940                            55.9736
#
#        Sample_Size     Sex                       Race  Grade  \
# 21             123    Male  Black or African American    9th
# 30             100  Female         Hispanic or Latino    9th
# 46             150   Total  Black or African American  Total
# 64             200    Male  Black or African American  Total
# 69             626    Male         Hispanic or Latino  Total
# ...            ...     ...                        ...    ...
# 315679         153    Male                      Total   11th
# 315698         340   Total  Black or African American   10th
# 315700         521   Total                      White   10th
# 315709         402  Female                      White  Total
# 315714         160   Total                      White   10th
#
#                                      GeoLocation  LocationId  \
# 21                       (25.551603, -80.632692)       108.0
# 30       (41.70828019300046, -71.52247031399963)        44.0
# 46      (37.645970271000465, -84.77497104799966)        21.0
# 64       (31.31266064400046, -92.44568007099969)        22.0
# 69      (31.827240407000488, -99.42677020599967)        48.0
# ...                                          ...         ...
# 315679   (32.84057112200048, -86.63186076199969)         1.0
# 315698   (39.29058096400047, -76.60926011099963)        24.0
# 315700  (43.23554134300048, -108.10983035299967)        56.0
# 315709                   (26.190096, -80.365865)       106.0
# 315714   (35.47203135600046, -97.52107021399968)        40.0
#
#        StratificationType
# 21                  Local
# 30                  State
# 46                  State
# 64                  State
# 69                  State
# ...                   ...
# 315679              State
# 315698              State
# 315700              State
# 315709              Local
# 315714              State
#
# [24065 rows x 19 columns]

# %%
copy_df.drop_duplicates(subset=None,keep='first', inplace= False, ignore_index= False)
# Out:
#         YEAR LocationAbbr           LocationDesc ShortQuestionText  \
# 21      1999           MM  Miami-Dade County, FL       Weight loss
# 30      2005           RI           Rhode Island       Weight loss
# 46      2011           KY               Kentucky       Weight loss
# 64      2007           LA              Louisiana       Weight loss
# 69      2009           TX                  Texas       Weight loss
# ...      ...          ...                    ...               ...
# 315679  2001           AL                Alabama       Weight loss
# 315698  2011           MD               Maryland       Weight loss
# 315700  2015           WY                Wyoming       Weight loss
# 315709  1995           FT     Broward County, FL       Weight loss
# 315714  2011           OK               Oklahoma       Weight loss
#
#                  Greater_Risk_Question  Greater_Risk_Data_Value  \
# 21      Were not trying to lose weight                  83.7466
# 30      Were not trying to lose weight                  46.8113
# 46      Were not trying to lose weight                  57.3838
# 64      Were not trying to lose weight                  71.1292
# 69      Were not trying to lose weight                  59.4503
# ...                                ...                      ...
# 315679  Were not trying to lose weight                  77.3953
# 315698  Were not trying to lose weight                  58.3476
# 315700  Were not trying to lose weight                  60.8925
# 315709  Were not trying to lose weight                  35.2309
# 315714  Were not trying to lose weight                  53.5417
#
#         Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 21                                74.6253                             90.0273
# 30                                38.6592                             55.1372
# 46                                48.8880                             65.4651
# 64                                59.7947                             80.3200
# 69                                53.8738                             64.7931
# ...                                   ...                                 ...
# 315679                            67.3788                             85.0200
# 315698                            50.8871                             65.4443
# 315700                            56.9041                             64.7406
# 315709                            30.2751                             40.5263
# 315714                            44.0264                             62.8060
#
#               Lesser_Risk_Question  Lesser_Risk_Data_Value  \
# 21      Were trying to lose weight                 16.2534
# 30      Were trying to lose weight                 53.1887
# 46      Were trying to lose weight                 42.6162
# 64      Were trying to lose weight                 28.8708
# 69      Were trying to lose weight                 40.5497
# ...                            ...                     ...
# 315679  Were trying to lose weight                 22.6047
# 315698  Were trying to lose weight                 41.6524
# 315700  Were trying to lose weight                 39.1075
# 315709  Were trying to lose weight                 64.7691
# 315714  Were trying to lose weight                 46.4583
#
#         Lesser_Risk_Low_Confidence_Limit  Lesser_Risk_High_Confidence_Limit  \
# 21                                9.9727                            25.3747
# 30                               44.8628                            61.3408
# 46                               34.5349                            51.1120
# 64                               19.6800                            40.2053
# 69                               35.2069                            46.1262
# ...                                  ...                                ...
# 315679                           14.9800                            32.6212
# 315698                           34.5557                            49.1129
# 315700                           35.2594                            43.0959
# 315709                           59.4737                            69.7249
# 315714                           37.1940                            55.9736
#
#        Sample_Size     Sex                       Race  Grade  \
# 21             123    Male  Black or African American    9th
# 30             100  Female         Hispanic or Latino    9th
# 46             150   Total  Black or African American  Total
# 64             200    Male  Black or African American  Total
# 69             626    Male         Hispanic or Latino  Total
# ...            ...     ...                        ...    ...
# 315679         153    Male                      Total   11th
# 315698         340   Total  Black or African American   10th
# 315700         521   Total                      White   10th
# 315709         402  Female                      White  Total
# 315714         160   Total                      White   10th
#
#                                      GeoLocation  LocationId  \
# 21                       (25.551603, -80.632692)       108.0
# 30       (41.70828019300046, -71.52247031399963)        44.0
# 46      (37.645970271000465, -84.77497104799966)        21.0
# 64       (31.31266064400046, -92.44568007099969)        22.0
# 69      (31.827240407000488, -99.42677020599967)        48.0
# ...                                          ...         ...
# 315679   (32.84057112200048, -86.63186076199969)         1.0
# 315698   (39.29058096400047, -76.60926011099963)        24.0
# 315700  (43.23554134300048, -108.10983035299967)        56.0
# 315709                   (26.190096, -80.365865)       106.0
# 315714   (35.47203135600046, -97.52107021399968)        40.0
#
#        StratificationType
# 21                  Local
# 30                  State
# 46                  State
# 64                  State
# 69                  State
# ...                   ...
# 315679              State
# 315698              State
# 315700              State
# 315709              Local
# 315714              State
#
# [24065 rows x 19 columns]

# %%
copy_df.sample(100)
# Out:
#         YEAR LocationAbbr      LocationDesc ShortQuestionText  \
# 120666  2011           UT              Utah       Weight loss
# 154343  2005           IN           Indiana       Weight loss
# 236730  1995           CH       Chicago, IL       Weight loss
# 30320   2013           PH  Philadelphia, PA       Weight loss
# 80367   2005           DA        Dallas, TX       Weight loss
# ...      ...          ...               ...               ...
# 300824  2001           WI         Wisconsin       Weight loss
# 244754  1999           NY          New York       Weight loss
# 206998  2009           SC    South Carolina       Weight loss
# 18690   2001           SD      South Dakota       Weight loss
# 292396  2009           NY          New York       Weight loss
#
#                  Greater_Risk_Question  Greater_Risk_Data_Value  \
# 120666  Were not trying to lose weight                  75.8966
# 154343  Were not trying to lose weight                  55.8983
# 236730  Were not trying to lose weight                  53.7697
# 30320   Were not trying to lose weight                  63.7302
# 80367   Were not trying to lose weight                  59.2147
# ...                                ...                      ...
# 300824  Were not trying to lose weight                  60.6861
# 244754  Were not trying to lose weight                  64.9416
# 206998  Were not trying to lose weight                  55.4084
# 18690   Were not trying to lose weight                  34.0890
# 292396  Were not trying to lose weight                  67.4855
#
#         Greater_Risk_Low_Confidence_Limit  Greater_Risk_High_Confidence_Limit  \
# 120666                            69.3538                             81.4168
# 154343                            52.1613                             59.5696
# 236730                            49.5092                             57.9759
# 30320                             57.4163                             69.6035
# 80367                             51.9110                             66.1329
# ...                                   ...                                 ...
# 300824                            46.8174                             73.0223
# 244754                            56.0862                             72.8748
# 206998                            46.8139                             63.6914
# 18690                             26.2674                             42.8849
# 292396                            61.1185                             73.2659
#
#               Lesser_Risk_Question  Lesser_Risk_Data_Value  \
# 120666  Were trying to lose weight                 24.1034
# 154343  Were trying to lose weight                 44.1017
# 236730  Were trying to lose weight                 46.2303
# 30320   Were trying to lose weight                 36.2698
# 80367   Were trying to lose weight                 40.7853
# ...                            ...                     ...
# 300824  Were trying to lose weight                 39.3139
# 244754  Were trying to lose weight                 35.0584
# 206998  Were trying to lose weight                 44.5916
# 18690   Were trying to lose weight                 65.9110
# 292396  Were trying to lose weight                 32.5145
#
#         Lesser_Risk_Low_Confidence_Limit  Lesser_Risk_High_Confidence_Limit  \
# 120666                           18.5832                            30.6462
# 154343                           40.4304                            47.8387
# 236730                           42.0241                            50.4908
# 30320                            30.3965                            42.5837
# 80367                            33.8671                            48.0890
# ...                                  ...                                ...
# 300824                           26.9777                            53.1826
# 244754                           27.1252                            43.9138
# 206998                           36.3086                            53.1861
# 18690                            57.1151                            73.7326
# 292396                           26.7341                            38.8815
#
#        Sample_Size     Sex                       Race  Grade  \
# 120666         143    Male                      White   12th
# 154343         409   Total                      Total    9th
# 236730       1,034  Female                      Total  Total
# 30320          148   Total  Black or African American   11th
# 80367          108   Total  Black or African American   10th
# ...            ...     ...                        ...    ...
# 300824         103   Total              Multiple Race  Total
# 244754         112   Total  Black or African American   10th
# 206998         266   Total                      Total   11th
# 18690          180  Female                      Total   12th
# 292396       1,422    Male                      Total   11th
#
#                                       GeoLocation  LocationId  \
# 120666  (39.360700171000474, -111.58713063499971)        49.0
# 154343   (39.766910452000445, -86.14996019399968)        18.0
# 236730                    (41.878114, -87.629798)       112.0
# 30320                     (39.952584, -75.165222)       124.0
# 80367                     (32.776664, -96.796988)       126.0
# ...                                           ...         ...
# 300824    (44.39319117400049, -89.81637074199966)        55.0
# 244754    (42.82700103200045, -75.54397042699964)        36.0
# 206998   (33.998821303000454, -81.04537120699968)        45.0
# 18690    (44.353130053000484, -100.3735306369997)        46.0
# 292396    (42.82700103200045, -75.54397042699964)        36.0
#
#        StratificationType
# 120666              State
# 154343              State
# 236730              Local
# 30320               Local
# 80367               Local
# ...                   ...
# 300824              State
# 244754              State
# 206998              State
# 18690               State
# 292396              State
#
# [100 rows x 19 columns]

# %%
copy_df.to_csv('Obesity Overweight and Weight Control Final Clean.csv')
